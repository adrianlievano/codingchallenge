# %%
import random
import string
import sys


VOWELS = "aeiou"
CONSONANTS = "".join(set(string.ascii_lowercase) - set(VOWELS))

def generate_word(length):
    word = ""
    for i in range(length):
        if i % 2 == 0:
            word += random.choice(CONSONANTS)
        else:
            word += random.choice(VOWELS)
    return word

if __name__ == "__main__":
    try:
        count = int(sys.argv[1])
    except:
        count = 5

    try:
        length = int(sys.argv[2])
    except:
        length = 6

    for i in range(count):
        print(generate_word(length))
# Out:
# kikoku
# naxoza
# wuketo
# depipa
# xumuhi

# %%
database=[]
for i in range(1000):
    database.append(generate_word(10))
    
database
# Out:
# ['kakonilivi',
#  'juqudesuwe',
#  'zopivebego',
#  'botexukutu',
#  'qihadaxino',
#  'biboveyatu',
#  'mujazezuza',
#  'caxigevuye',
#  'viqinavipu',
#  'goruvobive',
#  'yuyediparu',
#  'sejukimadu',
#  'qafiyuvama',
#  'jedihotigo',
#  'cabojubica',
#  'bipozuqevo',
#  'wesiluxesa',
#  'tajigifeve',
#  'xowugacayu',
#  'cijizakifi',
#  'vunoferogu',
#  'yajicoboqo',
#  'coyakatize',
#  'sigirowecu',
#  'tarihuzati',
#  'lequjesoca',
#  'zuniwoyefu',
#  'gakekigeyi',
#  'logoqemene',
#  'varilusoya',
#  'sobaleqezo',
#  'jojusediti',
#  'toyiselava',
#  'covotoqaxi',
#  'cutesikaye',
#  'cuxoxacomu',
#  'pahigolatu',
#  'bucadagime',
#  'yucobovihu',
#  'qogayogike',
#  'kulivavora',
#  'mosoponuxa',
#  'tiliwufapu',
#  'hahuniluka',
#  'xasozepigo',
#  'weniwadibe',
#  'fajemakivu',
#  'fepakuqoja',
#  'giroyiroma',
#  'pipomihetu',
#  'nepajoqeze',
#  'dulaneciri',
#  'gimuwiwako',
#  'rukejerudi',
#  'gijexedole',
#  'hexegotofa',
#  'dibamesobi',
#  'vutafapiya',
#  'xategudewi',
#  'yilabagaxu',
#  'bokifariwu',
#  'piqaboveli',
#  'yucirerazo',
#  'nacitazako',
#  'depopofubi',
#  'digozefofe',
#  'cowujiyibo',
#  'yijobihini',
#  'cubuvonehe',
#  'calayeqemu',
#  'mopubotuyo',
#  'kagiquhuyu',
#  'tameweraxa',
#  'lupaqeduzu',
#  'tumosawuke',
#  'mokozixela',
#  'mopetezoce',
#  'qipiwidoda',
#  'befiniceve',
#  'qajovinase',
#  'yovaqalexe',
#  'jekamawojo',
#  'zunifovupi',
#  'gocumijuli',
#  'giqarezeju',
#  'mucuwixige',
#  'moyezijehe',
#  'tesecifahi',
#  'kawafasexa',
#  'gexamaxaze',
#  'docevimuhu',
#  'deketususi',
#  'ficayulozi',
#  'gihedinajo',
#  'cobeyagapo',
#  'yiqucaseda',
#  'zurocesavi',
#  'xitamohefa',
#  'raxuwewaho',
#  'ridilesiga',
#  'nelemomiji',
#  'simedujoka',
#  'wolizonudu',
#  'cotizaheji',
#  'jozagijoje',
#  'pumelalima',
#  'furikituto',
#  'zihinocaxi',
#  'juvixatafi',
#  'juyamasoni',
#  'fazudaseve',
#  'xaducilova',
#  'napavibuse',
#  'neyohiciga',
#  'hidubicolo',
#  'burupumeci',
#  'nosanacejo',
#  'hukaraluda',
#  'cobodowisu',
#  'rocuhewolo',
#  'fuzerayacu',
#  'poxatoyofe',
#  'zibaqucafe',
#  'xaqubutule',
#  'socobuboto',
#  'katexuqelu',
#  'febifimoxi',
#  'rutuqoginu',
#  'xuyivexubu',
#  'hekogavusu',
#  'jawemehube',
#  'lokevawila',
#  'cofihoromi',
#  'jirofepude',
#  'xegidacahu',
#  'nesamohoge',
#  'micahetugi',
#  'vayahekuvu',
#  'lafitoxuri',
#  'zigihopude',
#  'zowenivumu',
#  'ripojijalu',
#  'fekebomuxu',
#  'moxukiqita',
#  'danarinoze',
#  'sekuyakige',
#  'xusakabuti',
#  'lovicocoje',
#  'hucegovuqi',
#  'guledigeru',
#  'pimamogejo',
#  'konatefifa',
#  'jokaqevoha',
#  'mefuwegeko',
#  'jixikuqixa',
#  'buvuseconi',
#  'qideyubose',
#  'dimulalofo',
#  'miwidawadu',
#  'dijalawevi',
#  'gasomohamo',
#  'wedojekabo',
#  'betepebixo',
#  'wadizideje',
#  'qasavapisa',
#  'zemikafome',
#  'golusutase',
#  'saqatimixa',
#  'heyetovecu',
#  'rahexenefe',
#  'wovekuwuve',
#  'xapesadeba',
#  'kaparoqawo',
#  'wozapakepo',
#  'gizuvehedi',
#  'naxocotela',
#  'qakuxanozo',
#  'xicixarice',
#  'nopekevana',
#  'goxuluqope',
#  'silaxicufa',
#  'pinasinixa',
#  'zivewofuyi',
#  'girimobefe',
#  'valeqacemi',
#  'zubavebimu',
#  'sosuxukare',
#  'mowacumane',
#  'micigarafi',
#  'kuxigaxuwu',
#  'besugeqiti',
#  'miqijowote',
#  'lisupohuko',
#  'qamurebiqu',
#  'wusejojohe',
#  'muyexajuru',
#  'vifutawucu',
#  'guhehisuqo',
#  'nawepamago',
#  'wiboxaduki',
#  'vedelotuxu',
#  'disorikaru',
#  'rujutelopo',
#  'xutewagero',
#  'zumaxuragu',
#  'kawalulufi',
#  'holavesuhu',
#  'pehusitovi',
#  'wafojodeja',
#  'raqewevuje',
#  'qenijanijo',
#  'basefoxile',
#  'sixixodale',
#  'ladajuveyi',
#  'gakadeheme',
#  'lexupemaxi',
#  'doloxowadu',
#  'cusofamato',
#  'qumatiliru',
#  'kifisisoha',
#  'puduborohi',
#  'gotefuyaze',
#  'nikuzijidi',
#  'tigobimano',
#  'kalolihola',
#  'xafahaweco',
#  'yiqogacafi',
#  'vafigizaja',
#  'risutayeta',
#  'qiduyuqoju',
#  'rivavinuve',
#  'ruzejufupa',
#  'gafezamova',
#  'sexopuzapa',
#  'cijiwudolu',
#  'giloqokubu',
#  'jofefeweje',
#  'yekexakave',
#  'camaruwoti',
#  'vorebabake',
#  'varukepuji',
#  'nopayozapo',
#  'rimudukeci',
#  'jopowoziva',
#  'xezopaceke',
#  'wequsazabe',
#  'xenukelibu',
#  'yapeyepuvu',
#  'yubovogako',
#  'teyagoreqe',
#  'vitevajagi',
#  'wunupekila',
#  'wukataruda',
#  'hugewinide',
#  'lomutupowu',
#  'jadevuziji',
#  'cotujukuba',
#  'jotumeyewu',
#  'rehebamono',
#  'qodeviluji',
#  'dikugepego',
#  'cagukufaje',
#  'taxucuhoce',
#  'kuvunixobe',
#  'yuboqiroqu',
#  'doyugunovo',
#  'fojulazoge',
#  'hasulututu',
#  'wepaduwari',
#  'dowavawoki',
#  'ditaseyawe',
#  'bozupomado',
#  'calebawohi',
#  'yunakatuze',
#  'hipiqojatu',
#  'caxuyubore',
#  'doqiviquda',
#  'boruqonaji',
#  'jademogeba',
#  'vevudipiyu',
#  'naraqineyi',
#  'tamozasoca',
#  'vefufiqaqi',
#  'yucaqehiwo',
#  'hegehureze',
#  'taniwulogu',
#  'nikaxutane',
#  'yezurezanu',
#  'gakeyelapi',
#  'fifehopile',
#  'raxaleyafu',
#  'pufaziquha',
#  'marigamevo',
#  'ritaleyaxi',
#  'rikuleqixo',
#  'kuwuhapoki',
#  'dajicoyopo',
#  'gidecuyama',
#  'qatorutoyu',
#  'roqozozabe',
#  'qozaqijebo',
#  'xanixaroqe',
#  'jogufetiji',
#  'gagivurilo',
#  'gitajusisi',
#  'fajugorewe',
#  'fuletaquce',
#  'qobetocawu',
#  'gisidutuga',
#  'nevanahiwa',
#  'rizulebohu',
#  'batukuxabe',
#  'lijekezuni',
#  'jebavizeve',
#  'benevuroye',
#  'fojayucere',
#  'lucuhosazu',
#  'nizumebode',
#  'qixorajoji',
#  'xetoxunojo',
#  'cakiyeyide',
#  'rozemugone',
#  'pubuciqopo',
#  'daterifiwo',
#  'lemilelifu',
#  'rawiwujadi',
#  'raxovumaye',
#  'vaxulijuci',
#  'luhowonevi',
#  'timazutodo',
#  'zucixepufo',
#  'suvefunomu',
#  'woquliraga',
#  'hulakixebu',
#  'zatiresobe',
#  'kayufifamo',
#  'jocatodome',
#  'ganonomudo',
#  'lacohayavo',
#  'pudulixila',
#  'wawopedeso',
#  'qozoreruvi',
#  'nenijedase',
#  'xakugowaqi',
#  'nacinapazu',
#  'yojixojusi',
#  'gehanuruxe',
#  'wosidavaqi',
#  'zidijehohe',
#  'baxikoriva',
#  'gosanikupo',
#  'xewilatofi',
#  'zijusowudu',
#  'favusazuwe',
#  'qilajefaje',
#  'tiyowewiku',
#  'cifeheyabo',
#  'xowacovocu',
#  'mobihavivu',
#  'wawidihaku',
#  'semoyevemi',
#  'nebexifuna',
#  'wexabuyema',
#  'bobiyuvope',
#  'buhobeviqu',
#  'bayojakayo',
#  'qileximiju',
#  'xeyozupoda',
#  'cejafexuni',
#  'lebujinora',
#  'powozapawu',
#  'nibeseruva',
#  'volatejeti',
#  'wenolamafi',
#  'tiganahaze',
#  'vahiwaxaka',
#  'hateqecalu',
#  'qunimubucu',
#  'belitupiso',
#  'sawicogopi',
#  'jutazurolu',
#  'hiluvugezi',
#  'zepeweqote',
#  'yobujuriko',
#  'rexivenoju',
#  'raberugexi',
#  'selamiwipa',
#  'yupunagaqi',
#  'pamobizata',
#  'qaminubepu',
#  'rohevowibu',
#  'nuyogeceqa',
#  'catureqoso',
#  'qufeyoqaja',
#  'woyoyuyuya',
#  'cukopuyupu',
#  'yoreveyice',
#  'gamihedayi',
#  'nohitigefu',
#  'ziwecodere',
#  'nucebureda',
#  'nezoriceya',
#  'kevasihaxi',
#  'gavutulayu',
#  'sasizinubi',
#  'bisokaline',
#  'benexeyebe',
#  'dayesohufa',
#  'kirevilapu',
#  'pubakeselo',
#  'ruxiriheze',
#  'hawiduruxu',
#  'cudodayuda',
#  'cacozojaho',
#  'zofigedako',
#  'nojekanubu',
#  'fusutaraqe',
#  'tavisoqide',
#  'wacutedaru',
#  'yuzofohuno',
#  'fonijifizo',
#  'hudiyikiri',
#  'moroxifetu',
#  'xehoduxaco',
#  'qezofaneji',
#  'naraparube',
#  'babatihezo',
#  'tajapobuve',
#  'hixitehebo',
#  'sapawibunu',
#  'dilotamodu',
#  'levijitoko',
#  'xusexolozo',
#  'sowutobowo',
#  'vicawefeba',
#  'dotudejimi',
#  'vemidijagu',
#  'comopusoti',
#  'zobagiqega',
#  'biyecicima',
#  'hinajisamo',
#  'dugilaceci',
#  'diwipobaji',
#  'kipigamisi',
#  'fonugobewi',
#  'kubitaxibo',
#  'copusakura',
#  'darayoqofu',
#  'xivemicacu',
#  'xuvuyaxanu',
#  'lazimeciza',
#  'sufayojelu',
#  'gevabuzufi',
#  'kezogutehu',
#  'faxohilixa',
#  'zabolicovu',
#  'qifotujada',
#  'heqexusahu',
#  'cukifojeji',
#  'bufolobiti',
#  'loqopupomu',
#  'guxipoluqu',
#  'kocesicuri',
#  'xivuyihuqo',
#  'yujuvogozo',
#  'qorosucaxo',
#  'kepiyasego',
#  'wetoceyuxo',
#  'rabafimeji',
#  'tuwocameva',
#  'sefufurizu',
#  'laqoxarupu',
#  'cuvavijowi',
#  'zuriwiceru',
#  'bodudivawu',
#  'jujujomidi',
#  'leyegozahi',
#  'suxedomabu',
#  'zamilecale',
#  'sipugaficu',
#  'nesuremepo',
#  'viloticazi',
#  'ruzuhacexo',
#  'tusawibine',
#  'heyoyohewi',
#  'dohixohica',
#  'sacuboditi',
#  'nuwejifufu',
#  'kacewurebo',
#  'loqisimemo',
#  'xumibiyive',
#  'dilowugiji',
#  'niwuvuvafa',
#  'feteqovini',
#  'makurulona',
#  'puyisazoze',
#  'vekasarapi',
#  'wacewozope',
#  'vofiseguzu',
#  'vurataxedo',
#  'fusadahibe',
#  'linasifaga',
#  'kabegodeya',
#  'suhekufajo',
#  'vipuxudilu',
#  'ruyoruzevu',
#  'herazinete',
#  'xiqebosave',
#  'dedevelahu',
#  'vavuzotutu',
#  'qotepaqoxe',
#  'mutuwuzudi',
#  'nuliyeqera',
#  'wileponipa',
#  'zoqeyehuco',
#  'kegefiwuso',
#  'xibovixume',
#  'dakalelivi',
#  'wujototebu',
#  'fehunagase',
#  'zewuxeteno',
#  'qeyuyekapa',
#  'muwiqerije',
#  'divojakoya',
#  'cohamamugi',
#  'befuhaguba',
#  'bixeloqobo',
#  'memaxivuwo',
#  'mejezepaku',
#  'faxanulaha',
#  'cigituqofo',
#  'rupumosade',
#  'qozofavuyu',
#  'wujemanaya',
#  'kozuqivuco',
#  'viwahiciyi',
#  'vibevaxeci',
#  'qasuvuriso',
#  'xejoxetove',
#  'bojoregoko',
#  'mocozarono',
#  'rujigiyice',
#  'muvagobora',
#  'dihepedugi',
#  'zubehugapo',
#  'lobimiwuna',
#  'turavateri',
#  'fawulubuko',
#  'gesixubewe',
#  'josanacusa',
#  'qewolagepe',
#  'xiwekihase',
#  'qirecubuli',
#  'kagomeleqe',
#  'gubopuxusu',
#  'yuzifujira',
#  'riqanefata',
#  'vetesiholu',
#  'puwecihape',
#  'vibatogoxe',
#  'qudigaxefe',
#  'hacabicahe',
#  'zazohunona',
#  'hudohageji',
#  'gudoqijici',
#  'xehofapeta',
#  'ripuhowobu',
#  'zosazaweno',
#  'povapibidi',
#  'tehuwapevu',
#  'zemepiduse',
#  'quqidevasa',
#  'panebuvufi',
#  'jubicosoxe',
#  'tacoberini',
#  'tebafiyuvi',
#  'haxakayeze',
#  'fevudocuqa',
#  'gejojegobo',
#  'naluforesa',
#  'pukuriyece',
#  'doqorahole',
#  'kezijapacu',
#  'nejolenicu',
#  'nigevasoti',
#  'qezumolona',
#  'jogapasiwa',
#  'lisuserutu',
#  'ciqoyabefu',
#  'foxenaqatu',
#  'xukubenisi',
#  'belivoliru',
#  'tuzefokide',
#  'nibetigego',
#  'xabusacosu',
#  'danovekeli',
#  'cobaxuwofo',
#  'xomecaceqe',
#  'cuyawekapa',
#  'hamoziyeli',
#  'totuhosali',
#  'jilifadibi',
#  'hufaliwizu',
#  'loxewohane',
#  'setimekudi',
#  'jutoqavifo',
#  'giqedaveja',
#  'casifaxosa',
#  'behetebivi',
#  'xovarogeso',
#  'husuwaxiwu',
#  'zufapefawi',
#  'jukewitope',
#  'hukeronaca',
#  'fisoceduta',
#  'kalofaduya',
#  'dojizisaju',
#  'tiluhewure',
#  'jakaquruko',
#  'nurebemicu',
#  'foqozosoli',
#  'pegijijica',
#  'luquxoyapa',
#  'bumapikopi',
#  'giyulacuqi',
#  'sipotedago',
#  'toruvoqeni',
#  'totipuzehu',
#  'vogijiqaso',
#  'favirekonu',
#  'tebilelede',
#  'rahocaneko',
#  'buxiradeso',
#  'qigebidino',
#  'moficadofa',
#  'reredupado',
#  'mecavucabo',
#  'sucilixoxe',
#  'howucozive',
#  'wupatozabi',
#  'molehequka',
#  'seyubajuzu',
#  'piwagatura',
#  'fovanofena',
#  'sadubukuhe',
#  'zuzonunija',
#  'fumufepele',
#  'julibepife',
#  'filewuzoso',
#  'yelamoriri',
#  'vilaxoyanu',
#  'gozohuqape',
#  'gafiqutana',
#  'qufaqifaqi',
#  'cevahojezo',
#  'sovamuqezo',
#  'qadumowepu',
#  'yurelemuzi',
#  'vibujefura',
#  'puwijehonu',
#  'nuqinecoyi',
#  'fategonoxe',
#  'zaxopajisu',
#  'yinewomuza',
#  'tefecepeni',
#  'wimanakagu',
#  'lopecaxane',
#  'lufepiseqa',
#  'taconevufe',
#  'bakuwoheso',
#  'kesovopoke',
#  'zavutidaha',
#  'dilaquyuke',
#  'suzinogemu',
#  'kuqanohahi',
#  'yonebuneha',
#  'jozajanadi',
#  'jehumibamo',
#  'rusuxucewe',
#  'bodasuveyi',
#  'haranisiwi',
#  'marutopafa',
#  'jujabelego',
#  'codasemebu',
#  'ritefasufe',
#  'dofabiwowi',
#  'zuvikilopu',
#  'vexekayovi',
#  'qagurexoxo',
#  'relinixuxo',
#  'liwumeculu',
#  'yehavekuga',
#  'negiqohigu',
#  'nafafufifu',
#  'zafumosiqu',
#  'wozukotema',
#  'mohoxogino',
#  'jomuhuqoru',
#  'fanajekiko',
#  'xuwokatela',
#  'kixevoyivi',
#  'zidisojafo',
#  'gedefayuku',
#  'vavevegofu',
#  'jacagekije',
#  'juquzotive',
#  'zizutupovo',
#  'jatodagori',
#  'yeguzogemu',
#  'hehinavevi',
#  'lezamebesa',
#  'vavarusafi',
#  'soqahudeso',
#  'digotuyuje',
#  'behetiyepe',
#  'zilayuhuyi',
#  'huxamuxuxi',
#  'sanizitijo',
#  'cejiboxapa',
#  'tebuvonuri',
#  'xerevopoki',
#  'nuwuhoyivi',
#  'wavucucapo',
#  'nutarokeli',
#  'pocayazifa',
#  'hiqovudaho',
#  'woxehidehi',
#  'nivetogaqo',
#  'yosuzaxeso',
#  'sudepinago',
#  'mayucafuyu',
#  'puruxabate',
#  'wihusezuke',
#  'lalasuvibu',
#  'mojileziru',
#  'vuzojazadu',
#  'rihiqorigu',
#  'kaqoyetuje',
#  'gaqagumezi',
#  'kowifafoca',
#  'hegijebohu',
#  'zuwuzumobu',
#  'gakorexaju',
#  'zoyuriqaho',
#  'qunaxivoma',
#  'lowihohifu',
#  'revomomato',
#  'wedoxalama',
#  'xilenozuya',
#  'xowanadaku',
#  'xopafacira',
#  'zepihebane',
#  'wudidecito',
#  'laluvemoxe',
#  'cifugejewa',
#  'pojalifucu',
#  'wagigasife',
#  'yugalukimo',
#  'muzuqamosu',
#  'fopoxilema',
#  'xogegogebo',
#  'goruzusoqu',
#  'juluvecobo',
#  'goxofuqeso',
#  'gayiruxito',
#  'wevilajinu',
#  'kivaporodu',
#  'giwisayeja',
#  'lisujakuso',
#  'qakuvekefi',
#  'woyexidifo',
#  'xeduvofalo',
#  'bivekahapo',
#  'ruqotayize',
#  'sololiwiwi',
#  'kedoluwapo',
#  'nacequqoha',
#  'kaqatofucu',
#  'hoqabecito',
#  'nafejotuya',
#  'wobulunuzi',
#  'sohukejupi',
#  'kepuxoyoje',
#  'neyuveceni',
#  'xajoxovona',
#  'fixogotiga',
#  'zelapasecu',
#  'wipojusaka',
#  'fawavahexa',
#  'qikojifayo',
#  'wetuhokiti',
#  'hiwicadezi',
#  'vunifutuwu',
#  'piyagizepi',
#  'fabufavuho',
#  'qecicuwasi',
#  'lafefavuta',
#  'qikaridevi',
#  'jebahiceyo',
#  'yecemixoma',
#  'juhenuguya',
#  'gazugopeto',
#  'yibefigaho',
#  'raboxoyipi',
#  'zadequvisa',
#  'vuxugelaza',
#  'yuvefadoze',
#  'momiholobi',
#  'faqosohuko',
#  'vitinamaga',
#  'hujawupami',
#  'hoyurihuqa',
#  'qopacewefo',
#  'hupudopexo',
#  'suwuyamepo',
#  'mokicapeye',
#  'wujebupuca',
#  'lotibitede',
#  'lojazomoxu',
#  'muyulitigo',
#  'haqubukihi',
#  'zesiyexuvu',
#  'cegajubiha',
#  'tiqalokuvi',
#  'viroqafeqo',
#  'wonadigoye',
#  'zupeqiqazu',
#  'qirizifivu',
#  'xilegobeso',
#  'cexibefaje',
#  'ruzomeroni',
#  'riritebedi',
#  'koqubedore',
#  'vuqeniloha',
#  'xetidudoxo',
#  'cayolumobu',
#  'somewopoli',
#  'huhujexubu',
#  'rowiqefaji',
#  'duqiniqaga',
#  'yoteledijo',
#  'locejecime',
#  'qotacoxomi',
#  'muzazelawe',
#  'sokovalihe',
#  'semelideru',
#  'tubuhoqoru',
#  'cofimizawe',
#  'leqecufapu',
#  'jeyelonata',
#  'welugedaki',
#  'xedixicoqu',
#  'varefodeqo',
#  'suziqegeno',
#  'tuyibeheqo',
#  'fozotojibi',
#  'zarulowepi',
#  'xatiyehimi',
#  'zuhaxubete',
#  'fifiluvina',
#  'puxijepawa',
#  'sibuqenute',
#  'pakuwuqula',
#  'lumodihiti',
#  'judihagazo',
#  'durafejira',
#  'lararavume',
#  'qigonorako',
#  'gakelahawa',
#  'tagicepiri',
#  'nocecitevu',
#  'lapuhapuhu',
#  'ziwevesasi',
#  'saqefiroce',
#  'rojaxosuye',
#  'pemapikici',
#  'jezexizilu',
#  'ticeyiguqo',
#  'vovocanaza',
#  'folatipipu',
#  'kixobesuga',
#  'bovizubidi',
#  'bobigelove',
#  'jasowotofe',
#  'husaxuxuge',
#  'lenufowodo',
#  'hifahuvija',
#  'zeboxenuvo',
#  'jifugozuxa',
#  'linodocebu',
#  'susafegowi',
#  'sinadezule',
#  'mazadomeni',
#  'tirefawedo',
#  'birafamuzo',
#  'nezacahuye',
#  'naletudeze',
#  'dekuxewuqu',
#  'tebokinode',
#  'davavilaxa',
#  'zalodemiva',
#  'xoqodexepi',
#  'wawoqirexe',
#  'yehucineli',
#  'behezoqiru',
#  'yetehetaqo',
#  'dotiravoco',
#  'sugejazulu',
#  'gurikusere',
#  'cupicojuri',
#  'cugopupafu',
#  'riqohowage',
#  'kawesizere',
#  'himonenuxe',
#  'tigamukuku',
#  'hagipevowi',
#  'xizihofuvi',
#  'wimugipujo',
#  'qocogagabo',
#  'suyiveguzo',
#  'hikoqoxiri',
#  'nagijihete',
#  'viyenosehe',
#  'davixotawa',
#  'ganefayofu',
#  'wukenowoza',
#  'dulahobabo',
#  'faqukabahu',
#  'xezamuyece',
#  'cidekuwudo',
#  'vagomizuki',
#  'nenoraveke',
#  'dasureneyo',
#  'cupulazobu',
#  'cesazexogu',
#  'buvumasuxe',
#  'xagodejuku',
#  'didahidojo',
#  'vuqajeyayi',
#  'hapekicesa',
#  'hoqihewihu',
#  'zotidusula',
#  'buquvowega',
#  'racelecebu',
#  'vutaqakihu',
#  'rohexeceku',
#  'pevewuvido',
#  'porazuzilo',
#  'zukorayofa',
#  'qeyamuquwa',
#  'jawuvecihu',
#  'farawusoli',
#  'jiwezesuci',
#  'royexoladi',
#  'butetiroca',
#  'viritegibu',
#  'nobojeweka',
#  'bijonesizu',
#  'zelicuyomo',
#  'yopoluliwo',
#  'wefocuxipe',
#  'xodibuqugo',
#  'votavazare',
#  'bowomawaxi',
#  'nexaxixuru',
#  'vutijalofe',
#  'hefacawowo',
#  'gatepuqedo',
#  'jivoribipu',
#  'roqosumubi',
#  'dozoqiqelu',
#  'comumisuwe',
#  'cufakiqixa',
#  'towomekije',
#  'watekuvogi',
#  'sekefiqaru',
#  'vajokenulo',
#  'kenesolece',
#  'wexabixora',
#  'lojoxinizi',
#  'zoburupudu',
#  'zehowomoge',
#  'mepohibenu',
#  'huwujagofo',
#  'vamofatina',
#  'kocuduyiho',
#  'zogewohici',
#  'tokohejuta',
#  'saquhuvini',
#  'bokevopuha',
#  'pobiraceni',
#  'kocokekajo',
#  'nocaxewofe',
#  'zetuqowepo',
#  'sawizosomu',
#  'weduhitace',
#  'beyacisuwu',
#  'viyezuwusu',
#  'bitepekefe',
#  'mocevuyife']

# %%
def extract(query):
    """Implement this method using the `query` API call, for example:
    query("abracadar") #=> ["abracadara"] using the default query method in main()
    """
    
    #database=[]
    #for i in range(100):
        #database.append(generate_word(10))
        
    # YOUR CODE HERE
    #database = ["abracadara", "al", "alice", "alicia", "allen", "alter", "altercation", "bob", "eve", "evening", "event", "eventually", "mallory"]
    #database = 

    #Try this database!!
    database = ['ASD','ASD','GOHASD','GOHAN','ASDD,','GTGTG','GTGsdsd','lo','adrian','guano','jimcarrey','grunt','MasterChief','AAAAAAAA','AAA','AAB','AABC','AAACC','AAACD','AAACVX','$','a','b','c','d',"abracadara", "al", "alice","#312Yomama","#412Yomama","#512Yomama","#612Yomama","#712Yomama","#812Yomama", "alicia", "allen", "alter",'913KILLA','123Banyo','xx#Chaosxx#','23Yawwhey' "altercation","amap","ammap","azap","azzopa","AcePilota19993","bob", "bzaop", "eve", "evening", "event", "eventually", "mallory"]
    database = sorted(set(database))

    def getWords(data):
        words=[]
        for i in range(len(data)):
            word=data[i]
            words.append(word)
        return words
    
    def getLetters(allWords):
        #Initialize chars and Letters matrix
        chars = []    
        fls=[]
        for x in range(len(allWords)):
            listChar=list(allWords[x])
            chars.append(listChar)   
        #return chars
        for i in range(len(allWords)):
            fl=chars[i][0:]
            fls.append(fl)
        return fls
    
    
    remainder_database=(database)
    words=getWords(database)
    letters=getLetters(words)

###########################################def getFirstOrderLetters:#########################################
    #Initialize list for 1st order combination terms
    flc=[]
    print("  ")
    print('Remaining usernames: {} '.format(remainder_database))

    for i in range(len(letters[:][0:])):
        flc.append(letters[i][0])
    #Gets unique 1-letter combinations & sorts them is lexicographically sorted 
    flc = sorted(list(set(flc)))
    print("  ")
    print( 'This is the set of the first order terms: {}'.format(flc))

    #Calls query on each 1st order combination in order and removes from the original database
    for i in range(len(flc)):
        remainder_database=sorted(list(set(remainder_database)-set(query(flc[i]))))
    print("  ")
    print('Remaining usernames: {} '.format(remainder_database))
    print("    ")

    #PRINT SUCCESS MESAGE IF ALL USERS HAVE BEEN IDENTIFIED
    if (len(remainder_database)<1):
        print('Congratulations! We identified all users in our database')
    else:
        print('Find higher order features')
        
###########################################def getSecondOrderLetters:#########################################
        #Creates 1st char removal list
        remove_flc = []
        for i in range(len(database)):
            if (len(letters[i][0:]) < 2):
                remove_flc.append(database[i])

    #filters out 1-char characters
        remainder_database=sorted(list(set(database)-set(remove_flc))) 
        print("  ")
        print("We will filter out {} terms before discovering 2nd order features".format(remove_flc))
        print("  ")
        print('This is the post-filtered database: {}'.format(remainder_database))
        print("  ")

    #Initialize list for 2nd order combination terms
        words=getWords(remainder_database)
        letters=getLetters(words)
        slc=[]

        for i in range(len(letters[:][0:])):
            slc.append(letters[i][0]+letters[i][1])
        #Gets unique 2-letter combinations & sorts them is lexicographically sorted 
        slc = sorted(list(set(slc)))
        print("    ")
        print( 'This is the set of the second order terms: {}'.format(slc))


    #Calls query on each 2nd order combination in order and removes from the original database
        for i in range(len(slc)):
            remainder_database=sorted(list(set(remainder_database)-set(query(slc[i]))))
        print("  ")
        print('Remaining usernames: {} '.format(remainder_database))
        print("  ")

    #PRINT SUCCESS MESSAGE IF ALL USERS HAVE BEEN IDENTIFIED
    #############Check for remaining usernames; proceed to filter using third order combinations#############
        if (len(remainder_database)<1):
            print('Congratulations! We identified all users in our database only using 1st and 2nd order terms')
        else:
            print('Find higher order terms')
    ###########################################def getThirdOrderLetters:#########################################

            print(" ")
            print(letters)
            #This restarts the database and allows the 3rd order feature extraction algorithm to remove 1-char and 2-char length usernames
            remainder_database=(database)
            words=getWords(database)
            letters=getLetters(words)
            print(" ")
        
            #Creates 2nd char removal list
            remove_slc = []
            for i in range(len(database)):
                if (len(letters[i][0:]) <3 and len(letters[i][0:]) > 1 ):
                    remove_slc.append(database[i])
                
            #filters out 1-char characters
            remainder_database=sorted(list(set(database)-set(remove_slc)-set(remove_flc))) 
            print("  ")
            print("We will filter out {} and {} terms before discovering 3rd order features".format(remove_flc,remove_slc))
            print("  ")
            print('This is the post-filtered database: {}'.format(remainder_database))
            print("  ")
        
            #Reinitialize list for 3rd order feature extraction
            words=getWords(remainder_database)
            letters=getLetters(words)
            tlc=[]

            for j in range(len(letters)):
                tlc.append(letters[j][0]+letters[j][1]+letters[j][2])
            #Gets unique 3-letter combinations & sorts them is lexicographically sorted 
            tlc = sorted(list(set(tlc)))
            print("  ")
            print( 'This is the set of the third order terms: {}'.format(tlc))

            #Calls query on each 3rd order combination in order and removes from the original database
            for i in range(len(tlc)):
                remainder_database=sorted(list(set(remainder_database)-set(query(tlc[i]))))
            print("  ")
            print('Remaining usernames: {} '.format(remainder_database))
            print("    ")


            #PRINT SUCCESS MESSAGE IF ALL USERS HAVE BEEN IDENTIFIED
            if (len(remainder_database)<1):
                print('Congratulations! We identified all users in our database using 1st, 2nd, and 3rd order features')
            else:
                print('Find higher order terms')

    qu = len(flc)+len(slc)+len(tlc)
    #########OUTPUT ALL USERS IN LEX ORDER

    print("    ")
    print('Our features: ')
    print("    ")
    print(flc)
    print("    ")
    print(slc)
    print("    ")
    print(tlc)
    print("    ")
    print('Number of querys to extract features: {}'.format(qu))
    print('Number of usernames: {}'.format(len(database)))
    
    #OUTPUT ALL USERS IN LEX ORDER
    print("    ")
    print('Our features:')
    print(flc)
    print("    ")
    print(slc)
    print("    ")
    print(tlc)

    output = []

    #Logic: Call query on each ith element of first order features; check if len(remaining usernames) = 0; 
    #if not, continue to loop until first order features run out; if there still exists usernames, call queries on
    #each jth element of second order features; check if len(remaining_database)=0; 
    #if not, continue to loop until second order featuers run out;

    print("    ")
    print("    ")

    #Rebuilding portion of our database using 1st order features
    for i in range(len(flc)):
        output=sorted(output+query(flc[i]))
    print(" ")
    print('This is our dataset after using our 1st order features to rebuild the original dataset:')
    print(" ")
    print(output)

    #Checks if output is less than the entire database; finds unique additions using 2nd order terms and rebuilds output
    if (len(output)<len(database)):
        for j in range(len(slc)):
            output=sorted(set(output+query(slc[j])))

    print(" ")
    print('This is our dataset after using our 2nd order features to rebuild the original dataset:')
    print(" ")
    print(output)


    #Checks if output is less than the entire database; finds unique additions using 3rd order terms and rebuilds output
    if (len(output)<len(database)):
        for k in range(len(tlc)):
            output=sorted(set(output+query(tlc[k])))

    print(" ")
    print('This is our dataset after using our 3rd order features to rebuild the original dataset:')
    print(" ")
    print(output)

    print(" ")
    print('This is our original dataset:')
    print(" ")
    print(database)
    print(" ")
    print('Successful extraction of all usernames in the database')

    return output

def main():
    """Runs your solution -- no need to update (except to maybe change the database)."""
    # Simple implementation of the autocomplete API
    #database = ["abracadara", "al", "alice", "alicia", "allen", "alter", "altercation", "bob", "eve", "evening", "event", "eventually", "mallory"]
    database = ['ASD','ASD','GOHASD','GOHAN','ASDD,','GTGTG','GTGsdsd','lo','adrian','guano','jimcarrey','grunt','MasterChief','AAAAAAAA','AAA','AAB','AABC','AAACC','AAACD','AAACVX','$','a','b','c','d',"abracadara", "al", "alice","#312Yomama","#412Yomama","#512Yomama","#612Yomama","#712Yomama","#812Yomama", "alicia", "allen", "alter",'913KILLA','123Banyo','xx#Chaosxx#','23Yawwhey' "altercation","amap","ammap","azap","azzopa","AcePilota19993","bob", "bzaop", "eve", "evening", "event", "eventually", "mallory"]
    query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]
    assert extract(query) == database

main()
# Out:
#
# Remaining usernames: ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '$', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'a', 'abracadara', 'adrian', 'al', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'b', 'bob', 'bzaop', 'c', 'd', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
# This is the set of the first order terms: ['#', '$', '1', '2', '9', 'A', 'G', 'M', 'a', 'b', 'c', 'd', 'e', 'g', 'j', 'l', 'm', 'x']
#
# Remaining usernames: ['#812Yomama', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa']
#
# Find higher order features
#
# We will filter out ['$', 'a', 'b', 'c', 'd'] terms before discovering 2nd order features
#
# This is the post-filtered database: ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'abracadara', 'adrian', 'al', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'bob', 'bzaop', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
#
# This is the set of the second order terms: ['#3', '#4', '#5', '#6', '#7', '#8', '12', '23', '91', 'AA', 'AS', 'Ac', 'GO', 'GT', 'Ma', 'ab', 'ad', 'al', 'am', 'az', 'bo', 'bz', 'ev', 'gr', 'gu', 'ji', 'lo', 'ma', 'xx']
#
# Remaining usernames: ['AAB', 'AABC']
#
# Find higher order terms
#
# [['#', '3', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['#', '4', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['#', '5', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['#', '6', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['#', '7', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['#', '8', '1', '2', 'Y', 'o', 'm', 'a', 'm', 'a'], ['1', '2', '3', 'B', 'a', 'n', 'y', 'o'], ['2', '3', 'Y', 'a', 'w', 'w', 'h', 'e', 'y', 'a', 'l', 't', 'e', 'r', 'c', 'a', 't', 'i', 'o', 'n'], ['9', '1', '3', 'K', 'I', 'L', 'L', 'A'], ['A', 'A', 'A'], ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A'], ['A', 'A', 'A', 'C', 'C'], ['A', 'A', 'A', 'C', 'D'], ['A', 'A', 'A', 'C', 'V', 'X'], ['A', 'A', 'B'], ['A', 'A', 'B', 'C'], ['A', 'S', 'D'], ['A', 'S', 'D', 'D', ','], ['A', 'c', 'e', 'P', 'i', 'l', 'o', 't', 'a', '1', '9', '9', '9', '3'], ['G', 'O', 'H', 'A', 'N'], ['G', 'O', 'H', 'A', 'S', 'D'], ['G', 'T', 'G', 'T', 'G'], ['G', 'T', 'G', 's', 'd', 's', 'd'], ['M', 'a', 's', 't', 'e', 'r', 'C', 'h', 'i', 'e', 'f'], ['a', 'b', 'r', 'a', 'c', 'a', 'd', 'a', 'r', 'a'], ['a', 'd', 'r', 'i', 'a', 'n'], ['a', 'l'], ['a', 'l', 'i', 'c', 'e'], ['a', 'l', 'i', 'c', 'i', 'a'], ['a', 'l', 'l', 'e', 'n'], ['a', 'l', 't', 'e', 'r'], ['a', 'm', 'a', 'p'], ['a', 'm', 'm', 'a', 'p'], ['a', 'z', 'a', 'p'], ['a', 'z', 'z', 'o', 'p', 'a'], ['b', 'o', 'b'], ['b', 'z', 'a', 'o', 'p'], ['e', 'v', 'e'], ['e', 'v', 'e', 'n', 'i', 'n', 'g'], ['e', 'v', 'e', 'n', 't'], ['e', 'v', 'e', 'n', 't', 'u', 'a', 'l', 'l', 'y'], ['g', 'r', 'u', 'n', 't'], ['g', 'u', 'a', 'n', 'o'], ['j', 'i', 'm', 'c', 'a', 'r', 'r', 'e', 'y'], ['l', 'o'], ['m', 'a', 'l', 'l', 'o', 'r', 'y'], ['x', 'x', '#', 'C', 'h', 'a', 'o', 's', 'x', 'x', '#']]
#
#
# We will filter out ['$', 'a', 'b', 'c', 'd'] and ['al', 'lo'] terms before discovering 3rd order features
#
# This is the post-filtered database: ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'abracadara', 'adrian', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'bob', 'bzaop', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'mallory', 'xx#Chaosxx#']
#
#
# This is the set of the third order terms: ['#31', '#41', '#51', '#61', '#71', '#81', '123', '23Y', '913', 'AAA', 'AAB', 'ASD', 'Ace', 'GOH', 'GTG', 'Mas', 'abr', 'adr', 'ali', 'all', 'alt', 'ama', 'amm', 'aza', 'azz', 'bob', 'bza', 'eve', 'gru', 'gua', 'jim', 'mal', 'xx#']
#
# Remaining usernames: []
#
# Congratulations! We identified all users in our database using 1st, 2nd, and 3rd order features
#
# Our features:
#
# ['#', '$', '1', '2', '9', 'A', 'G', 'M', 'a', 'b', 'c', 'd', 'e', 'g', 'j', 'l', 'm', 'x']
#
# ['#3', '#4', '#5', '#6', '#7', '#8', '12', '23', '91', 'AA', 'AS', 'Ac', 'GO', 'GT', 'Ma', 'ab', 'ad', 'al', 'am', 'az', 'bo', 'bz', 'ev', 'gr', 'gu', 'ji', 'lo', 'ma', 'xx']
#
# ['#31', '#41', '#51', '#61', '#71', '#81', '123', '23Y', '913', 'AAA', 'AAB', 'ASD', 'Ace', 'GOH', 'GTG', 'Mas', 'abr', 'adr', 'ali', 'all', 'alt', 'ama', 'amm', 'aza', 'azz', 'bob', 'bza', 'eve', 'gru', 'gua', 'jim', 'mal', 'xx#']
#
# Number of querys to extract features: 80
# Number of usernames: 52
#
# Our features:
# ['#', '$', '1', '2', '9', 'A', 'G', 'M', 'a', 'b', 'c', 'd', 'e', 'g', 'j', 'l', 'm', 'x']
#
# ['#3', '#4', '#5', '#6', '#7', '#8', '12', '23', '91', 'AA', 'AS', 'Ac', 'GO', 'GT', 'Ma', 'ab', 'ad', 'al', 'am', 'az', 'bo', 'bz', 'ev', 'gr', 'gu', 'ji', 'lo', 'ma', 'xx']
#
# ['#31', '#41', '#51', '#61', '#71', '#81', '123', '23Y', '913', 'AAA', 'AAB', 'ASD', 'Ace', 'GOH', 'GTG', 'Mas', 'abr', 'adr', 'ali', 'all', 'alt', 'ama', 'amm', 'aza', 'azz', 'bob', 'bza', 'eve', 'gru', 'gua', 'jim', 'mal', 'xx#']
#
#
#
# This is our dataset after using our 1st order features to rebuild the original dataset:
#
# ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '$', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'a', 'abracadara', 'adrian', 'al', 'alice', 'b', 'bob', 'bzaop', 'c', 'd', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
# This is our dataset after using our 2nd order features to rebuild the original dataset:
#
# ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '$', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'a', 'abracadara', 'adrian', 'al', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'b', 'bob', 'bzaop', 'c', 'd', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
# This is our dataset after using our 3rd order features to rebuild the original dataset:
#
# ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '$', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'a', 'abracadara', 'adrian', 'al', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'b', 'bob', 'bzaop', 'c', 'd', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
# This is our original dataset:
#
# ['#312Yomama', '#412Yomama', '#512Yomama', '#612Yomama', '#712Yomama', '#812Yomama', '$', '123Banyo', '23Yawwheyaltercation', '913KILLA', 'AAA', 'AAAAAAAA', 'AAACC', 'AAACD', 'AAACVX', 'AAB', 'AABC', 'ASD', 'ASDD,', 'AcePilota19993', 'GOHAN', 'GOHASD', 'GTGTG', 'GTGsdsd', 'MasterChief', 'a', 'abracadara', 'adrian', 'al', 'alice', 'alicia', 'allen', 'alter', 'amap', 'ammap', 'azap', 'azzopa', 'b', 'bob', 'bzaop', 'c', 'd', 'eve', 'evening', 'event', 'eventually', 'grunt', 'guano', 'jimcarrey', 'lo', 'mallory', 'xx#Chaosxx#']
#
# Successful extraction of all usernames in the database
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-5c8d75690794> in <module>()
#     239     assert extract(query) == database
#     240
# --> 241 main()
#
# <ipython-input-7-5c8d75690794> in main()
#     237     database = sorted(database)
#     238     query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]
# --> 239     assert extract(query) == database
#     240
#     241 main()
#
# AssertionError:
