# %%
import random
import string
import sys


VOWELS = "aeiou"
CONSONANTS = "".join(set(string.ascii_lowercase) - set(VOWELS))

def generate_word(length):
    word = ""
    for i in range(length):
        if i % 2 == 0:
            word += random.choice(CONSONANTS)
        else:
            word += random.choice(VOWELS)
    return word

if __name__ == "__main__":
    try:
        count = int(sys.argv[1])
    except:
        count = 5

    try:
        length = int(sys.argv[2])
    except:
        length = 6

    for i in range(count):
        generate_word(length)
        

import random
import string

database=[]

for i in range(5):
    #database.append(generate_word(30))
    #database.append(generate_word(30))
    #database.append(generate_word(6))
    #database.append(generate_word(6))
    #database.append(generate_word(6))
    database.append(generate_word(6))
    database.append(generate_word(5))
    database.append(generate_word(4))
    database.append(generate_word(3))
    database.append(generate_word(2))
    database.append(generate_word(1))
database = sorted(list(set(database)))

#Try me
#database = sorted(list(set(['%%%%%%%','%%%%%%%%%%%','vtavatv','yhyrhrt','tujtujtjy','etyjetyjetyj','etyjetyjetyj','%%%','myumyum','$$$$$$$','$$$$$$$$$','$$$$$$$$$$$$','$$$$$$$$$2','AS','ASDFASDF','TGRTRTH','RTHRTHRTHRT','ASDGSDHSG','yjujtyjtyj','ytytydnyt','dsvfasdfva','asvasdvasdvy','rgrgerg','ergergerg','vasdvasdvasdvdvadsvasdvasdvasdsdvasd','ynysrnsnfgnsfgnsfgn','$$$$','ADGAFBYY','BYSBSB','asdasda','asdvasdvtthddbtdtbdbdtbdtb','ASD','ASD','GOHASD','GOHAN','ASDD,','GTGTG','GTGsdsd','lo','adrian','guano','jimcarrey','grunt','MasterChief','AAAAAAAA','AAA','AAB','AABC','AAACC','AAACD','AAACVX','$','a','b','c','d',"abracadara", "al", "alice","#312Yomama","#412Yomama","#512Yomama","#612Yomama","#712Yomama","#812Yomama", "alicia", "allen", "alter",'913KILLA','123Banyo','xx#Chaosxx#','23Yawwhey' "altercation","amap","ammap","azap","azzopa","AcePilota19993","bob", "bzaop", "eve", "evening", "event", "eventually", "mallory"])))

print(len(database))
database
# Out:
# 29
# ['beh',
#  'boduba',
#  'buzon',
#  'daqi',
#  'disinu',
#  'g',
#  'guvalu',
#  'ko',
#  'kore',
#  'kosin',
#  'me',
#  'novo',
#  'pom',
#  'putiv',
#  'qu',
#  'sogiw',
#  'sososi',
#  'sujeh',
#  'suqo',
#  'te',
#  'v',
#  'vekami',
#  'wab',
#  'x',
#  'xa',
#  'ximo',
#  'xot',
#  'y',
#  'yin']

# %%
def getwords(data):
    words=[]
    for i in range(len(data)):
        word=data[i]
        words.append(word)
    return words

def getletters(words):
    
    #Initialize chars and Letters matrix
    chars = []    
    fls=[]
    for x in range(len(words)):
        listChar=list(words[x])
        chars.append(listChar)   
    #return chars

    for i in range(len(words)):
        fl=chars[i][0:]
        fls.append(fl)
    return fls

def word_filter(data, letters, remove_word_size):
    remove = []
    if remove_word_size == 0:
        []
    else:
        for i in range(len(data)):
            if (len(letters[i][0:]) < remove_word_size+1 and len(letters[i][0:]) > remove_word_size-1):
                remove.append(data[i])
        return remove

def remove_list_ele(mas_list,remove_list):
    from collections import Counter
    a = mas_list
    b= remove_list
    c=list(Counter(a)-Counter(b))
    return c

def checker(output,data, prefix_level):
    data=sorted(data)
    if len(output) == len(data):
        flag = True
        print('Congrats! We identified all users using {} set of prefixes'.format(prefix_level))
    else:
        flag = False
        print('Find higher order features')
    return flag

# %%
#This functions builds the set of all first, second, third, nth order prefixes

def get_all_prefixes(query, data):
    #Initializing prefix extraction algorithm
    remainder_data = data
    words = getwords(data)
    letters = getletters(words)
    sorted_words = sorted(data,key=len)
    max_prefix=sorted_words[-1]
    remove = []
    prefixes = []
    flag=False
    output = []
    
    #j counts number of prefix levels
    for j in range(len(max_prefix)):
        if (len(max_prefix) > j and flag == False):
                #Creates jth char removal list
            remove=word_filter(remainder_data,letters,j)
            remainder_data = remove_list_ele(remainder_data,remove)
            words = getwords(remainder_data)
            letters = getletters(words)     
            print(letters)
            print(len(letters))
            print(len(data))
            print(remainder_data)
            
            for i in range(len(data)):
                #prefixes.append(letters[i][0:(j+1)])
                prefixes.append(letters[i][0]+letters[i][1])
            
            from itertools import chain
            prefixes = list(chain.from_iterable(prefixes))
            
            print('')
            print(prefixes)
            
            #TO DO: REBUILD DATASET 
            for i in range(len(prefixes)):
                output=sorted(list(set(output+query(prefixes[i]))))
        
            #Check if you got all the names using prefixes
            flag=checker(output,data,j+1)
        
    return output

# %%
for j in range(3):
    print('This is loop j number {}'.format(j))
    for i in range(5):
        print(i)
# Out:
# This is loop j number 0
# 0
# 1
# 2
# 3
# 4
# This is loop j number 1
# 0
# 1
# 2
# 3
# 4
# This is loop j number 2
# 0
# 1
# 2
# 3
# 4

# %%
def extract(query, data):
    """Implement this method using the `query` API call, for example:
    query("abracadar") #=> ["abracadara"] using the default query method in main()
    """
    # YOUR CODE HERE
    output=get_all_prefixes(query, sorted(list(set(data))))
    return output

def main():
    """Runs your solution -- no need to update (except to maybe change the database)."""
 
    import random
    import string
    import sys

    VOWELS = "aeiou"
    CONSONANTS = "".join(set(string.ascii_lowercase) - set(VOWELS))

    def generate_word(length):
        word = ""
        for i in range(length):
            if i % 2 == 0:
                word += random.choice(CONSONANTS)
            else:
                word += random.choice(VOWELS)
        return word

    if __name__ == "__main__":
        try:
            count = int(sys.argv[1])
        except:
            count = 5

        try:
            length = int(sys.argv[2])
        except:
            length = 6

        for i in range(count):
            generate_word(length)

    database=[]

    #generates X # of words, lenth generate_word(y)
    for i in range(50):
        #database.append(generate_word(200000))
        #database.append(generate_word(20000))
        #database.append(generate_word(2000))
        #database.append(generate_word(200))
        #database.append(generate_word(20))
        #database.append(generate_word(19))
        #database.append(generate_word(18))
        #database.append(generate_word(17))
        #database.append(generate_word(16))
        #database.append(generate_word(15))
        #database.append(generate_word(14))
        #database.append(generate_word(13))
        #database.append(generate_word(12))
        #database.append(generate_word(11))        
        #database.append(generate_word(10))
        #database.append(generate_word(9))
        #database.append(generate_word(8))
        #database.append(generate_word(7))
        database.append(generate_word(6))
        database.append(generate_word(5))
        database.append(generate_word(4))
        database.append(generate_word(3))
        database.append(generate_word(2))
        database.append(generate_word(1))
    database = sorted(list(set(database)))

    #Try me - Handles Capital letters and special characters
    #database = sorted(list(set(['%%%%%%%','%%%%%%%%%%%','vtavatv','yhyrhrt','tujtujtjy','etyjetyjetyj','etyjetyjetyj','%%%','myumyum','$$$$$$$','$$$$$$$$$','$$$$$$$$$$$$','$$$$$$$$$2','AS','ASDFASDF','TGRTRTH','RTHRTHRTHRT','ASDGSDHSG','yjujtyjtyj','ytytydnyt','dsvfasdfva','asvasdvasdvy','rgrgerg','ergergerg','vasdvasdvasdvdvadsvasdvasdvasdsdvasd','ynysrnsnfgnsfgnsfgn','$$$$','ADGAFBYY','BYSBSB','asdasda','asdvasdvtthddbtdtbdbdtbdtb','ASD','ASD','GOHASD','GOHAN','ASDD,','GTGTG','GTGsdsd','lo','adrian','guano','jimcarrey','grunt','MasterChief','AAAAAAAA','AAA','AAB','AABC','AAACC','AAACD','AAACVX','$','a','b','c','d',"abracadara", "al", "alice","#312Yomama","#412Yomama","#512Yomama","#612Yomama","#712Yomama","#812Yomama", "alicia", "allen", "alter",'913KILLA','123Banyo','xx#Chaosxx#','23Yawwhey' "altercation","amap","ammap","azap","azzopa","AcePilota19993","bob", "bzaop", "eve", "evening", "event", "eventually", "mallory"])))
    print('{} is the length of our database'.format(len(database)))    
    query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]
    print(database)
    assert extract(query, database) == database
    
main()
# Out:
# 262 is the length of our database
# ['b', 'bad', 'bafi', 'bebe', 'bid', 'bifip', 'bimi', 'biniy', 'bir', 'bis', 'bisiza', 'bixogo', 'bo', 'bobu', 'bov', 'c', 'ca', 'cafeg', 'cavuma', 'ced', 'cipas', 'ciq', 'ciwo', 'co', 'cohixu', 'coviwa', 'cowi', 'coxo', 'cu', 'cuh', 'cuwohe', 'd', 'da', 'dabovi', 'dadogi', 'de', 'def', 'deluyi', 'dilake', 'dimas', 'doki', 'duja', 'duvujo', 'f', 'fagot', 'fede', 'femi', 'fepi', 'few', 'fewir', 'fez', 'fike', 'filij', 'fisos', 'fo', 'funoxi', 'fuv', 'g', 'garaga', 'gato', 'genanu', 'gidik', 'gih', 'go', 'govini', 'gu', 'gup', 'gupa', 'gupit', 'h', 'ha', 'haqig', 'he', 'hexiv', 'hihifi', 'hije', 'hoqeni', 'how', 'hu', 'huba', 'hufuq', 'hug', 'hume', 'huni', 'huvaju', 'hux', 'j', 'jazago', 'jibu', 'jili', 'jipok', 'joqox', 'jusi', 'k', 'ka', 'kaga', 'kage', 'kebimo', 'ki', 'kib', 'kibepi', 'ko', 'koz', 'ku', 'kucej', 'l', 'laqa', 'le', 'lin', 'lo', 'lomum', 'lot', 'loxo', 'lubena', 'luc', 'lug', 'luted', 'luvor', 'm', 'mafoju', 'maso', 'me', 'meh', 'meq', 'mici', 'miji', 'mireno', 'mokive', 'moril', 'mozeco', 'mut', 'n', 'naco', 'naqu', 'naz', 'necad', 'nereno', 'no', 'nuga', 'nujer', 'nuvusu', 'p', 'pa', 'paq', 'par', 'peferi', 'pifi', 'pixef', 'po', 'posesi', 'posuq', 'pukax', 'q', 'qabame', 'qaye', 'qe', 'qebadi', 'qek', 'qemac', 'qici', 'qilof', 'qireli', 'qoki', 'qone', 'qor', 'quder', 'qugaro', 'r', 'raw', 'recu', 'ri', 'rij', 'rob', 'run', 'runu', 'ruraba', 's', 'sa', 'sah', 'salu', 'satu', 'sicij', 'sid', 'sijiki', 'suli', 't', 'ta', 'tapiwe', 'tataz', 'te', 'teb', 'ti', 'til', 'tohob', 'tot', 'tu', 'tuv', 'v', 'va', 'vaj', 'vatife', 'vi', 'vipepe', 'vitud', 'viwuce', 'vo', 'vonol', 'vu', 'w', 'wa', 'wamum', 'weboc', 'webope', 'wi', 'wikas', 'wocas', 'woliy', 'woz', 'wudil', 'wuwe', 'x', 'xapu', 'xe', 'xemigu', 'xenabi', 'xif', 'xixaxa', 'xizir', 'xo', 'xosiv', 'xuxa', 'y', 'ya', 'ye', 'yecaj', 'yega', 'yer', 'yesu', 'yevo', 'yex', 'yobubo', 'yomol', 'yu', 'yubut', 'yusug', 'z', 'zab', 'zad', 'zavupu', 'zefovo', 'zejihu', 'zibihu', 'ziqeco', 'zivo', 'zolic', 'zoy', 'zoyas', 'zu', 'zubu', 'zum', 'zutez', 'zuwey']
# [['b'], ['b', 'a', 'd'], ['b', 'a', 'f', 'i'], ['b', 'e', 'b', 'e'], ['b', 'i', 'd'], ['b', 'i', 'f', 'i', 'p'], ['b', 'i', 'm', 'i'], ['b', 'i', 'n', 'i', 'y'], ['b', 'i', 'r'], ['b', 'i', 's'], ['b', 'i', 's', 'i', 'z', 'a'], ['b', 'i', 'x', 'o', 'g', 'o'], ['b', 'o'], ['b', 'o', 'b', 'u'], ['b', 'o', 'v'], ['c'], ['c', 'a'], ['c', 'a', 'f', 'e', 'g'], ['c', 'a', 'v', 'u', 'm', 'a'], ['c', 'e', 'd'], ['c', 'i', 'p', 'a', 's'], ['c', 'i', 'q'], ['c', 'i', 'w', 'o'], ['c', 'o'], ['c', 'o', 'h', 'i', 'x', 'u'], ['c', 'o', 'v', 'i', 'w', 'a'], ['c', 'o', 'w', 'i'], ['c', 'o', 'x', 'o'], ['c', 'u'], ['c', 'u', 'h'], ['c', 'u', 'w', 'o', 'h', 'e'], ['d'], ['d', 'a'], ['d', 'a', 'b', 'o', 'v', 'i'], ['d', 'a', 'd', 'o', 'g', 'i'], ['d', 'e'], ['d', 'e', 'f'], ['d', 'e', 'l', 'u', 'y', 'i'], ['d', 'i', 'l', 'a', 'k', 'e'], ['d', 'i', 'm', 'a', 's'], ['d', 'o', 'k', 'i'], ['d', 'u', 'j', 'a'], ['d', 'u', 'v', 'u', 'j', 'o'], ['f'], ['f', 'a', 'g', 'o', 't'], ['f', 'e', 'd', 'e'], ['f', 'e', 'm', 'i'], ['f', 'e', 'p', 'i'], ['f', 'e', 'w'], ['f', 'e', 'w', 'i', 'r'], ['f', 'e', 'z'], ['f', 'i', 'k', 'e'], ['f', 'i', 'l', 'i', 'j'], ['f', 'i', 's', 'o', 's'], ['f', 'o'], ['f', 'u', 'n', 'o', 'x', 'i'], ['f', 'u', 'v'], ['g'], ['g', 'a', 'r', 'a', 'g', 'a'], ['g', 'a', 't', 'o'], ['g', 'e', 'n', 'a', 'n', 'u'], ['g', 'i', 'd', 'i', 'k'], ['g', 'i', 'h'], ['g', 'o'], ['g', 'o', 'v', 'i', 'n', 'i'], ['g', 'u'], ['g', 'u', 'p'], ['g', 'u', 'p', 'a'], ['g', 'u', 'p', 'i', 't'], ['h'], ['h', 'a'], ['h', 'a', 'q', 'i', 'g'], ['h', 'e'], ['h', 'e', 'x', 'i', 'v'], ['h', 'i', 'h', 'i', 'f', 'i'], ['h', 'i', 'j', 'e'], ['h', 'o', 'q', 'e', 'n', 'i'], ['h', 'o', 'w'], ['h', 'u'], ['h', 'u', 'b', 'a'], ['h', 'u', 'f', 'u', 'q'], ['h', 'u', 'g'], ['h', 'u', 'm', 'e'], ['h', 'u', 'n', 'i'], ['h', 'u', 'v', 'a', 'j', 'u'], ['h', 'u', 'x'], ['j'], ['j', 'a', 'z', 'a', 'g', 'o'], ['j', 'i', 'b', 'u'], ['j', 'i', 'l', 'i'], ['j', 'i', 'p', 'o', 'k'], ['j', 'o', 'q', 'o', 'x'], ['j', 'u', 's', 'i'], ['k'], ['k', 'a'], ['k', 'a', 'g', 'a'], ['k', 'a', 'g', 'e'], ['k', 'e', 'b', 'i', 'm', 'o'], ['k', 'i'], ['k', 'i', 'b'], ['k', 'i', 'b', 'e', 'p', 'i'], ['k', 'o'], ['k', 'o', 'z'], ['k', 'u'], ['k', 'u', 'c', 'e', 'j'], ['l'], ['l', 'a', 'q', 'a'], ['l', 'e'], ['l', 'i', 'n'], ['l', 'o'], ['l', 'o', 'm', 'u', 'm'], ['l', 'o', 't'], ['l', 'o', 'x', 'o'], ['l', 'u', 'b', 'e', 'n', 'a'], ['l', 'u', 'c'], ['l', 'u', 'g'], ['l', 'u', 't', 'e', 'd'], ['l', 'u', 'v', 'o', 'r'], ['m'], ['m', 'a', 'f', 'o', 'j', 'u'], ['m', 'a', 's', 'o'], ['m', 'e'], ['m', 'e', 'h'], ['m', 'e', 'q'], ['m', 'i', 'c', 'i'], ['m', 'i', 'j', 'i'], ['m', 'i', 'r', 'e', 'n', 'o'], ['m', 'o', 'k', 'i', 'v', 'e'], ['m', 'o', 'r', 'i', 'l'], ['m', 'o', 'z', 'e', 'c', 'o'], ['m', 'u', 't'], ['n'], ['n', 'a', 'c', 'o'], ['n', 'a', 'q', 'u'], ['n', 'a', 'z'], ['n', 'e', 'c', 'a', 'd'], ['n', 'e', 'r', 'e', 'n', 'o'], ['n', 'o'], ['n', 'u', 'g', 'a'], ['n', 'u', 'j', 'e', 'r'], ['n', 'u', 'v', 'u', 's', 'u'], ['p'], ['p', 'a'], ['p', 'a', 'q'], ['p', 'a', 'r'], ['p', 'e', 'f', 'e', 'r', 'i'], ['p', 'i', 'f', 'i'], ['p', 'i', 'x', 'e', 'f'], ['p', 'o'], ['p', 'o', 's', 'e', 's', 'i'], ['p', 'o', 's', 'u', 'q'], ['p', 'u', 'k', 'a', 'x'], ['q'], ['q', 'a', 'b', 'a', 'm', 'e'], ['q', 'a', 'y', 'e'], ['q', 'e'], ['q', 'e', 'b', 'a', 'd', 'i'], ['q', 'e', 'k'], ['q', 'e', 'm', 'a', 'c'], ['q', 'i', 'c', 'i'], ['q', 'i', 'l', 'o', 'f'], ['q', 'i', 'r', 'e', 'l', 'i'], ['q', 'o', 'k', 'i'], ['q', 'o', 'n', 'e'], ['q', 'o', 'r'], ['q', 'u', 'd', 'e', 'r'], ['q', 'u', 'g', 'a', 'r', 'o'], ['r'], ['r', 'a', 'w'], ['r', 'e', 'c', 'u'], ['r', 'i'], ['r', 'i', 'j'], ['r', 'o', 'b'], ['r', 'u', 'n'], ['r', 'u', 'n', 'u'], ['r', 'u', 'r', 'a', 'b', 'a'], ['s'], ['s', 'a'], ['s', 'a', 'h'], ['s', 'a', 'l', 'u'], ['s', 'a', 't', 'u'], ['s', 'i', 'c', 'i', 'j'], ['s', 'i', 'd'], ['s', 'i', 'j', 'i', 'k', 'i'], ['s', 'u', 'l', 'i'], ['t'], ['t', 'a'], ['t', 'a', 'p', 'i', 'w', 'e'], ['t', 'a', 't', 'a', 'z'], [ ...
# 262
# 262
# ['b', 'bad', 'bafi', 'bebe', 'bid', 'bifip', 'bimi', 'biniy', 'bir', 'bis', 'bisiza', 'bixogo', 'bo', 'bobu', 'bov', 'c', 'ca', 'cafeg', 'cavuma', 'ced', 'cipas', 'ciq', 'ciwo', 'co', 'cohixu', 'coviwa', 'cowi', 'coxo', 'cu', 'cuh', 'cuwohe', 'd', 'da', 'dabovi', 'dadogi', 'de', 'def', 'deluyi', 'dilake', 'dimas', 'doki', 'duja', 'duvujo', 'f', 'fagot', 'fede', 'femi', 'fepi', 'few', 'fewir', 'fez', 'fike', 'filij', 'fisos', 'fo', 'funoxi', 'fuv', 'g', 'garaga', 'gato', 'genanu', 'gidik', 'gih', 'go', 'govini', 'gu', 'gup', 'gupa', 'gupit', 'h', 'ha', 'haqig', 'he', 'hexiv', 'hihifi', 'hije', 'hoqeni', 'how', 'hu', 'huba', 'hufuq', 'hug', 'hume', 'huni', 'huvaju', 'hux', 'j', 'jazago', 'jibu', 'jili', 'jipok', 'joqox', 'jusi', 'k', 'ka', 'kaga', 'kage', 'kebimo', 'ki', 'kib', 'kibepi', 'ko', 'koz', 'ku', 'kucej', 'l', 'laqa', 'le', 'lin', 'lo', 'lomum', 'lot', 'loxo', 'lubena', 'luc', 'lug', 'luted', 'luvor', 'm', 'mafoju', 'maso', 'me', 'meh', 'meq', 'mici', 'miji', 'mireno', 'mokive', 'moril', 'mozeco', 'mut', 'n', 'naco', 'naqu', 'naz', 'necad', 'nereno', 'no', 'nuga', 'nujer', 'nuvusu', 'p', 'pa', 'paq', 'par', 'peferi', 'pifi', 'pixef', 'po', 'posesi', 'posuq', 'pukax', 'q', 'qabame', 'qaye', 'qe', 'qebadi', 'qek', 'qemac', 'qici', 'qilof', 'qireli', 'qoki', 'qone', 'qor', 'quder', 'qugaro', 'r', 'raw', 'recu', 'ri', 'rij', 'rob', 'run', 'runu', 'ruraba', 's', 'sa', 'sah', 'salu', 'satu', 'sicij', 'sid', 'sijiki', 'suli', 't', 'ta', 'tapiwe', 'tataz', 'te', 'teb', 'ti', 'til', 'tohob', 'tot', 'tu', 'tuv', 'v', 'va', 'vaj', 'vatife', 'vi', 'vipepe', 'vitud', 'viwuce', 'vo', 'vonol', 'vu', 'w', 'wa', 'wamum', 'weboc', 'webope', 'wi', 'wikas', 'wocas', 'woliy', 'woz', 'wudil', 'wuwe', 'x', 'xapu', 'xe', 'xemigu', 'xenabi', 'xif', 'xixaxa', 'xizir', 'xo', 'xosiv', 'xuxa', 'y', 'ya', 'ye', 'yecaj', 'yega', 'yer', 'yesu', 'yevo', 'yex', 'yobubo', 'yomol', 'yu', 'yubut', 'yusug', 'z', 'zab', 'zad', 'zavupu', 'zefovo', 'zejihu', 'zibihu', 'ziqeco', 'zivo', 'zolic', 'zoy', 'zoyas', 'zu', 'zubu', 'zum', 'zutez', 'zuwey']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-f69d2e78235a> in <module>()
#      77     assert extract(query, database) == database
#      78
# ---> 79 main()
#
# <ipython-input-5-f69d2e78235a> in main()
#      75     query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]
#      76     print(database)
# ---> 77     assert extract(query, database) == database
#      78
#      79 main()
#
# <ipython-input-5-f69d2e78235a> in extract(query, data)
#       4     """
#       5     # YOUR CODE HERE
# ----> 6     output=get_all_prefixes(query, sorted(list(set(data))))
#       7     return output
#       8
#
# <ipython-input-3-5cd86b805a16> in get_all_prefixes(query, data)
#      31             for i in range(len(remainder_data)):
#      32                 #prefixes.append(letters[i][0:(j+1)])
# ---> 33                 prefixes.append(letters[i][0]+letters[i][1])
#      34
#      35             from itertools import chain
#
# IndexError: list index out of range

# %%
data = ['bac','fzt','a','bc']

test = []
for i in range(len(let)):
        test.append(let[i][0]+let[i][1])
#print(test)


remainder_data = data
words = getwords(data)
letters = getletters(words)
sorted_words = sorted(data,key=len)
max_prefix=sorted_words[-1]
remove = []
prefixes = []
flag=False
output = []

for j in range(len(remainder_data)):
    if(len(max_prefix) > j and flag == False):
        remove=word_filter(remainder_data,letters,j)
        remainder_data = remove_list_ele(remainder_data,remove)
        words= getwords(remainder_data)
        letters = getletters(words)
        letters[0][0:j+1]=[''.join(letters[0][0:j+1])]
        print(remainder_data)
    
    for i in range(len(data)):
        prefixes.append(letters[i][j])

    print(prefixes)

x = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
x[3:6] = [''.join(x[3:6])]
x
# Out:
# ['bac', 'fzt', 'a', 'bc']
# ['bac', 'fzt', 'bc']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-181663cb6202> in <module>()
#      27
#      28     for i in range(len(data)):
# ---> 29         prefixes.append(letters[i][j])
#      30
#      31 print(test)
#
# IndexError: list index out of range
