# %%
def extract(query):
    """extract takes in a `query` API function (which returns the first 5 usernames, lexicographically sorted,
    that start with a prefix) and returns the sorted list of all usernames in the database.
    For example, the `query` function in provided in `main` works as follows:
    
    query("a") #=> ["abracadara", "al", "alice", "alicia", "allen"]
    query("ab") #=> ["abracadara"]
    The following implementation would pass the assertion in `main`, but is not a correct solution since it
    works only for that example `query`:
    def extract(query):
        return query("ab") + query("al") + query("altercation") + query("b") + query("el") + query("ev") + query("m")
    Your goal is to write an `extract` method that is correct for any provided `query`.
    """
    query('a')

    # YOUR CODE HERE
    return [...]

def main():
    """Runs your solution -- no need to update (except to maybe try out different databases)."""
    # Sample implementation of the autocomplete API
    database = ["abracadara", "al", "alice"]
    query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]
    #assert extract(query) == database

main()

# %%
import random
import string
import sys


VOWELS = "aeiou"
CONSONANTS = "".join(set(string.ascii_lowercase) - set(VOWELS))

def generate_word(length):
    word = ""
    for i in range(length):
        if i % 2 == 0:
            word += random.choice(CONSONANTS)
        else:
            word += random.choice(VOWELS)
    return word

if __name__ == "__main__":
    try:
        count = int(sys.argv[1])
    except:
        count = 5

    try:
        length = int(sys.argv[2])
    except:
        length = 6

    for i in range(count):
        generate_word(length)
        

import random
import string

database=[]

for i in range(500):
    #database.append(generate_word(30))
    #database.append(generate_word(30))
    #database.append(generate_word(6))
    #database.append(generate_word(6))
    #database.append(generate_word(6))
    #database.append(generate_word(6))
    #database.append(generate_word(5))
    database.append(generate_word(4))
    database.append(generate_word(3))
    database.append(generate_word(2))
    database.append(generate_word(1))
database = sorted(list(set(database)))

#Try me
#database = sorted(list(set(['%%%%%%%','%%%%%%%%%%%','vtavatv','yhyrhrt','tujtujtjy','etyjetyjetyj','etyjetyjetyj','%%%','myumyum','$$$$$$$','$$$$$$$$$','$$$$$$$$$$$$','$$$$$$$$$2','AS','ASDFASDF','TGRTRTH','RTHRTHRTHRT','ASDGSDHSG','yjujtyjtyj','ytytydnyt','dsvfasdfva','asvasdvasdvy','rgrgerg','ergergerg','vasdvasdvasdvdvadsvasdvasdvasdsdvasd','ynysrnsnfgnsfgnsfgn','$$$$','ADGAFBYY','BYSBSB','asdasda','asdvasdvtthddbtdtbdbdtbdtb','ASD','ASD','GOHASD','GOHAN','ASDD,','GTGTG','GTGsdsd','lo','adrian','guano','jimcarrey','grunt','MasterChief','AAAAAAAA','AAA','AAB','AABC','AAACC','AAACD','AAACVX','$','a','b','c','d',"abracadara", "al", "alice","#312Yomama","#412Yomama","#512Yomama","#612Yomama","#712Yomama","#812Yomama", "alicia", "allen", "alter",'913KILLA','123Banyo','xx#Chaosxx#','23Yawwhey' "altercation","amap","ammap","azap","azzopa","AcePilota19993","bob", "bzaop", "eve", "evening", "event", "eventually", "mallory"])))

print(len(database))
database
# Out:
# 1064
# ['b',
#  'ba',
#  'badi',
#  'baf',
#  'bak',
#  'bake',
#  'bala',
#  'bam',
#  'bav',
#  'be',
#  'bed',
#  'bega',
#  'beje',
#  'beko',
#  'ber',
#  'bera',
#  'bet',
#  'bexe',
#  'bi',
#  'bib',
#  'bin',
#  'biqo',
#  'bir',
#  'biv',
#  'bive',
#  'biw',
#  'bixo',
#  'bo',
#  'bob',
#  'bof',
#  'boga',
#  'boh',
#  'boju',
#  'bom',
#  'bome',
#  'bop',
#  'boy',
#  'boz',
#  'bu',
#  'bubu',
#  'bud',
#  'buhu',
#  'buka',
#  'bup',
#  'busu',
#  'buto',
#  'buya',
#  'buza',
#  'c',
#  'ca',
#  'cafu',
#  'cag',
#  'caj',
#  'caji',
#  'caku',
#  'cam',
#  'cama',
#  'cara',
#  'cav',
#  'caw',
#  'cawi',
#  'ce',
#  'cec',
#  'ceg',
#  'cej',
#  'ceke',
#  'cel',
#  'cep',
#  'cer',
#  'ces',
#  'cev',
#  'ceye',
#  'ci',
#  'cib',
#  'cibo',
#  'cica',
#  'ciga',
#  'cik',
#  'cive',
#  'civi',
#  'ciw',
#  'co',
#  'coco',
#  'cog',
#  'coj',
#  'con',
#  'coq',
#  'cox',
#  'coy',
#  'coyo',
#  'cudi',
#  'culo',
#  'cumu',
#  'cuni',
#  'cut',
#  'd',
#  'da',
#  'dace',
#  'dade',
#  'dahe',
#  'daq',
#  'daw',
#  'dawi',
#  'dax',
#  'de',
#  'defe',
#  'deh',
#  'deko',
#  'del',
#  'dep',
#  'depu',
#  'dev',
#  'dex',
#  'dez',
#  'di',
#  'dic',
#  'dica',
#  'digu',
#  'diha',
#  'dir',
#  'diso',
#  'dito',
#  'diwi',
#  'diwo',
#  'dixa',
#  'diy',
#  'do',
#  'doc',
#  'dolo',
#  'dope',
#  'doqi',
#  'dot',
#  'dowu',
#  'doxi',
#  'du',
#  'dub',
#  'dud',
#  'duf',
#  'duj',
#  'duk',
#  'dum',
#  'dur',
#  'dutu',
#  'dux',
#  'f',
#  'fa',
#  'fab',
#  'fadu',
#  'faja',
#  'fal',
#  'fan',
#  'fana',
#  'far',
#  'fas',
#  'faw',
#  'fawi',
#  'fax',
#  'fayi',
#  'fe',
#  'feq',
#  'fi',
#  'fica',
#  'fil',
#  'fila',
#  'fipo',
#  'fis',
#  'fiwa',
#  'fix',
#  'fo',
#  'fob',
#  'fohe',
#  'foj',
#  'fom',
#  'fop',
#  'fowi',
#  'foz',
#  'fu',
#  'fuc',
#  'fuce',
#  'fuf',
#  'fure',
#  'fut',
#  'fuw',
#  'g',
#  'ga',
#  'gac',
#  'gafo',
#  'gaj',
#  'gak',
#  'gal',
#  'gam',
#  'gap',
#  'gar',
#  'gato',
#  'gax',
#  'gaza',
#  'ge',
#  'gega',
#  'geh',
#  'gej',
#  'geno',
#  'ges',
#  'get',
#  'geva',
#  'geyi',
#  'gi',
#  'giba',
#  'gic',
#  'gifi',
#  'giho',
#  'gik',
#  'gim',
#  'gip',
#  'gire',
#  'giro',
#  'giw',
#  'giwo',
#  'gix',
#  'giy',
#  'gize',
#  'go',
#  'goba',
#  'god',
#  'gofo',
#  'goj',
#  'gojo',
#  'gop',
#  'gor',
#  'gotu',
#  'gow',
#  'gox',
#  'goy',
#  'goza',
#  'gozi',
#  'gozu',
#  'gu',
#  'gud',
#  'gufa',
#  'guj',
#  'guja',
#  'gul',
#  'guy',
#  'guyo',
#  'h',
#  'ha',
#  'hac',
#  'hade',
#  'hag',
#  'halo',
#  'hana',
#  'hape',
#  'haq',
#  'hayu',
#  'he',
#  'hede',
#  'hege',
#  'heh',
#  'hek',
#  'hela',
#  'hem',
#  'hemu',
#  'heq',
#  'hesa',
#  'hi',
#  'hicu',
#  'hig',
#  'hihi',
#  'hiri',
#  'hix',
#  'hiy',
#  'ho',
#  'hoda',
#  'hoj',
#  'hu',
#  'hud',
#  'huho',
#  'huj',
#  'huke',
#  'hun',
#  'hupi',
#  'husa',
#  'huv',
#  'huw',
#  'huwu',
#  'huy',
#  'j',
#  'ja',
#  'jafu',
#  'jak',
#  'janu',
#  'jap',
#  'japa',
#  'jar',
#  'jaxa',
#  'jaz',
#  'je',
#  'jecu',
#  'jefe',
#  'jeh',
#  'jeja',
#  'jeji',
#  'jel',
#  'jela',
#  'jem',
#  'jemi',
#  'jero',
#  'jes',
#  'jey',
#  'jeza',
#  'ji',
#  'jibo',
#  'jil',
#  'jisi',
#  'jiti',
#  'jiv',
#  'jiwa',
#  'jiy',
#  'jo',
#  'jof',
#  'joji',
#  'jolu',
#  'jom',
#  'jopi',
#  'jor',
#  'joru',
#  'joxi',
#  'jozu',
#  'ju',
#  'jud',
#  'jupo',
#  'juq',
#  'jur',
#  'juta',
#  'juti',
#  'juv',
#  'juyu',
#  'k',
#  'ka',
#  'kabi',
#  'kagi',
#  'kam',
#  'kan',
#  'kas',
#  'kav',
#  'ke',
#  'keci',
#  'ked',
#  'kego',
#  'kel',
#  'kewi',
#  'kexa',
#  'ki',
#  'kic',
#  'kice',
#  'kid',
#  'kiha',
#  'kija',
#  'kije',
#  'kimu',
#  'kiq',
#  'kito',
#  'kix',
#  'ko',
#  'kob',
#  'koh',
#  'koho',
#  'koja',
#  'koji',
#  'koko',
#  'kom',
#  'kop',
#  'kose',
#  'koyo',
#  'koyu',
#  'ku',
#  'kuba',
#  'kug',
#  'kuji',
#  'kula',
#  'kun',
#  'kup',
#  'kut',
#  'kuxe',
#  'kuy',
#  'l',
#  'la',
#  'lab',
#  'ladu',
#  'lam',
#  'lav',
#  'le',
#  'lehi',
#  'lej',
#  'leku',
#  'lele',
#  'lena',
#  'lep',
#  'les',
#  'lesu',
#  'let',
#  'lev',
#  'lex',
#  'lexe',
#  'lexu',
#  'lez',
#  'lezo',
#  'li',
#  'lif',
#  'lifo',
#  'lila',
#  'lip',
#  'lir',
#  'lo',
#  'lob',
#  'loco',
#  'log',
#  'lom',
#  'lone',
#  'loq',
#  'lov',
#  'love',
#  'lowu',
#  'loy',
#  'lu',
#  'lub',
#  'luf',
#  'luge',
#  'luki',
#  'lun',
#  'lunu',
#  'luso',
#  'luv',
#  'luwi',
#  'luxe',
#  'luyu',
#  'm',
#  'ma',
#  'mabe',
#  'macu',
#  'mafu',
#  'mat',
#  'mav',
#  'mavu',
#  'maw',
#  'me',
#  'meco',
#  'megi',
#  'meha',
#  'mete',
#  'mi',
#  'mibe',
#  'mic',
#  'midi',
#  'mife',
#  'migi',
#  'mih',
#  'miq',
#  'miso',
#  'mo',
#  'mob',
#  'mok',
#  'mom',
#  'mon',
#  'moq',
#  'mos',
#  'mosa',
#  'moso',
#  'moy',
#  'mu',
#  'mubi',
#  'muda',
#  'mug',
#  'muji',
#  'muk',
#  'muki',
#  'mul',
#  'mum',
#  'munu',
#  'mupu',
#  'muq',
#  'mura',
#  'muro',
#  'muv',
#  'muva',
#  'muyu',
#  'n',
#  'na',
#  'nab',
#  'nag',
#  'nala',
#  'name',
#  'naq',
#  'naqo',
#  'nar',
#  'nav',
#  'nayu',
#  'naz',
#  'nazi',
#  'ne',
#  'nek',
#  'nemo',
#  'nepi',
#  'nev',
#  'ni',
#  'nici',
#  'nifu',
#  'nij',
#  'niq',
#  'nita',
#  'nito',
#  'niv',
#  'niy',
#  'niz',
#  'nofo',
#  'nole',
#  'nona',
#  'not',
#  'now',
#  'nox',
#  'noye',
#  'nu',
#  'nub',
#  'nuj',
#  'nuji',
#  'nuk',
#  'nup',
#  'nupa',
#  'nuqu',
#  'nuru',
#  'nuw',
#  'nuxu',
#  'p',
#  'pa',
#  'pab',
#  'pahe',
#  'paj',
#  'paqi',
#  'paw',
#  'pax',
#  'pay',
#  'pe',
#  'pega',
#  'pegi',
#  'peh',
#  'pep',
#  'peqe',
#  'peto',
#  'pex',
#  'pez',
#  'peza',
#  'pi',
#  'pid',
#  'pif',
#  'pifo',
#  'pig',
#  'pih',
#  'pihu',
#  'pij',
#  'pim',
#  'pin',
#  'pinu',
#  'pipo',
#  'piq',
#  'pitu',
#  'pizu',
#  'po',
#  'poc',
#  'pod',
#  'pogi',
#  'poli',
#  'pon',
#  'pona',
#  'poni',
#  'ponu',
#  'pot',
#  'pow',
#  'poyi',
#  'pozu',
#  'pu',
#  'puc',
#  'puf',
#  'pupu',
#  'pus',
#  'puti',
#  'puv',
#  'puwo',
#  'puya',
#  'puye',
#  'q',
#  'qa',
#  'qaj',
#  'qali',
#  'qam',
#  'qaro',
#  'qav',
#  'qava',
#  'qazi',
#  'qe',
#  'qeci',
#  'qedi',
#  'qef',
#  'qeje',
#  'qenu',
#  'qeqa',
#  'qes',
#  'qew',
#  'qi',
#  'qibu',
#  'qidi',
#  'qido',
#  'qifu',
#  'qih',
#  'qike',
#  'qima',
#  'qita',
#  'qiti',
#  'qiv',
#  'qivi',
#  'qiwi',
#  'qix',
#  'qixi',
#  'qizi',
#  'qo',
#  'qob',
#  'qofo',
#  'qol',
#  'qola',
#  'qole',
#  'qolo',
#  'qoro',
#  'qox',
#  'qoz',
#  'qu',
#  'quk',
#  'qun',
#  'qupo',
#  'qur',
#  'quro',
#  'qus',
#  'qusi',
#  'quv',
#  'quw',
#  'r',
#  'ra',
#  'rac',
#  'raf',
#  'rafe',
#  'rah',
#  'raj',
#  'rak',
#  'raku',
#  'raqa',
#  'ratu',
#  'rav',
#  'rax',
#  'raze',
#  're',
#  'reb',
#  'reda',
#  'ref',
#  'refe',
#  'reg',
#  'remu',
#  'repi',
#  'reto',
#  'rey',
#  'ri',
#  'riba',
#  'rid',
#  'rife',
#  'ril',
#  'rima',
#  'rimu',
#  'rin',
#  'rip',
#  'ripe',
#  'riq',
#  'riy',
#  'rizi',
#  'ro',
#  'rofu',
#  'rog',
#  'rohi',
#  'rope',
#  'ros',
#  'royi',
#  'roz',
#  'ru',
#  'rufu',
#  'ruhe',
#  'runu',
#  'ruqe',
#  'rure',
#  'rus',
#  'rut',
#  'ruwa',
#  's',
#  'sa',
#  'sac',
#  'saha',
#  'saj',
#  'sala',
#  'samo',
#  'sap',
#  'saq',
#  'sat',
#  'sata',
#  'sawu',
#  'say',
#  'se',
#  'sebe',
#  'seco',
#  'secu',
#  'sefu',
#  'sek',
#  'sel',
#  'semi',
#  'seta',
#  'sev',
#  'sez',
#  'si',
#  'sice',
#  'sig',
#  'siko',
#  'siq',
#  'sisa',
#  'sisu',
#  'sivi',
#  'so',
#  'sob',
#  'sod',
#  'soj',
#  'sok',
#  'sol',
#  'somi',
#  'sop',
#  'sor',
#  'sot',
#  'sota',
#  'sow',
#  'soxi',
#  'su',
#  'suc',
#  'sude',
#  'suf',
#  'sufo',
#  'sug',
#  'suli',
#  'sumo',
#  'sup',
#  'suq',
#  'sur',
#  'suso',
#  'suv',
#  'sux',
#  'suya',
#  't',
#  'ta',
#  'tabe',
#  'taci',
#  'tafa',
#  'tag',
#  'tak',
#  'tan',
#  'tapu',
#  'tat',
#  'tatu',
#  'tave',
#  'tax',
#  'tay',
#  'te',
#  'tefi',
#  'teg',
#  'tehi',
#  'tena',
#  'tes',
#  'tevi',
#  'tey',
#  'teya',
#  'ti',
#  'tic',
#  'tiga',
#  'tij',
#  'tiku',
#  'tin',
#  'to',
#  'tofu',
#  'top',
#  'tor',
#  'tovo',
#  'toxu',
#  'toyi',
#  'tu',
#  'tubo',
#  'tuca',
#  'tufu',
#  'tuh',
#  'tumu',
#  'tun',
#  'tur',
#  'turo',
#  'tus',
#  'tutu',
#  'tuxe',
#  'tuyi',
#  'v',
#  'va',
#  'vac',
#  'vad',
#  'vafu',
#  'vag',
#  'val',
#  'vano',
#  'var',
#  'vat',
#  'vato',
#  'vawe',
#  'vaya',
#  'vayi',
#  'vaz',
#  've',
#  'veba',
#  'veko',
#  'veku',
#  'veru',
#  'vewo',
#  'veya',
#  'veza',
#  'vi',
#  'vifa',
#  'vife',
#  'vih',
#  'vij',
#  'vil',
#  'vimo',
#  'viq',
#  'viv',
#  'viw',
#  'vixa',
#  'viza',
#  'vo',
#  'voj',
#  'voja',
#  'vom',
#  'voq',
#  'voqu',
#  'voru',
#  'vowo',
#  'voye',
#  'vu',
#  'vudi',
#  'vujo',
#  'vumi',
#  'vuni',
#  'vupu',
#  'vuv',
#  'vuw',
#  'w',
#  'wa',
#  'wab',
#  'waca',
#  'wah',
#  'waj',
#  'wak',
#  'wala',
#  'wana',
#  'wawa',
#  'wawo',
#  'wax',
#  'waz',
#  'we',
#  'webo',
#  'wej',
#  'weje',
#  'wela',
#  'wemi',
#  'wen',
#  'weno',
#  'wes',
#  'wesu',
#  'wet',
#  'wewi',
#  'wex',
#  'weya',
#  'wi',
#  'wici',
#  'wiga',
#  'wih',
#  'wijo',
#  'wivu',
#  'wixa',
#  'wixo',
#  'wize',
#  'wo',
#  'wobu',
#  'wof',
#  'woq',
#  'woti',
#  'wov',
#  'wowi',
#  'wox',
#  'woy',
#  'wu',
#  'wuce',
#  'wug',
#  'wuh',
#  'wuha',
#  'wum',
#  'wup',
#  'wuri',
#  'wusi',
#  'x',
#  'xa',
#  'xafo',
#  'xag',
#  'xak',
#  'xal',
#  'xana',
#  'xar',
#  'xas',
#  'xavi',
#  'xax',
#  'xe',
#  'xeco',
#  'xedu',
#  'xefe',
#  'xeh',
#  'xeko',
#  'xel',
#  'xela',
#  'xen',
#  'xev',
#  'xeva',
#  'xexa',
#  'xey',
#  'xeyo',
#  'xi',
#  'xik',
#  'xipa',
#  'xipi',
#  'xiq',
#  'xis',
#  'xit',
#  'xo',
#  'xoca',
#  'xogu',
#  'xoho',
#  'xoju',
#  'xone',
#  'xoqu',
#  'xor',
#  'xov',
#  'xu',
#  'xuca',
#  'xuge',
#  'xuhe',
#  'xuj',
#  'xuje',
#  'xum',
#  'xumu',
#  'xun',
#  'xuq',
#  'xuwi',
#  'xuxu',
#  'xuz',
#  'xuzo',
#  'y',
#  'ya',
#  'yada',
#  'yah',
#  'yahe',
#  'yaja',
#  'yan',
#  'yane',
#  'yaqa',
#  'ye',
#  'yeko',
#  'yem',
#  'yen',
#  'yevo',
#  'yew',
#  'yi',
#  'yib',
#  'yicu',
#  'yid',
#  'yidi',
#  'yije',
#  'yil',
#  'yim',
#  'yip',
#  'yiqa',
#  'yiri',
#  'yis',
#  'yiz',
#  'yo',
#  'yocu',
#  'yof',
#  'yohi',
#  'yol',
#  'yoma',
#  ...]

# %%
def get_all_prefixes(data):
    sorted_words = sorted(data,key=len)
    max_prefix=sorted_words[-1]
    print(len(max_prefix))
    
    chars = []
    prefixes = []
    for x in range(len(data)):
        listChar=list(data[x])
        chars.append(listChar)   
    #return chars
    letters = []
    for i in range(len(data)):
        letter=chars[i][0:]
        letters.append(letter)
    #return letters
    
    for j in range(len(max_prefix)):
        if (len(max_prefix) > j):
            for i in range(len(data))
            prefixes[j].append(letters[i][j])
    
    #prefixes = ([item for sublist in prefixes for item in sublist])

    return prefixes
# Out:
#   File "<ipython-input-299-fd228bb1e767>", line 20
#     for i in range(len(data))
#                              ^
# SyntaxError: invalid syntax

# %%
def getwords(data):
    words=[]
    for i in range(len(data)):
        word=data[i]
        words.append(word)
    return words

def getletters(words):
    
    #Initialize chars and Letters matrix
    chars = []    
    fls=[]
    for x in range(len(words)):
        listChar=list(words[x])
        chars.append(listChar)   
    #return chars

    for i in range(len(words)):
        fl=chars[i][0:]
        fls.append(fl)
    return fls

def word_filter(data, letters, remove_word_size):
    remove = []
    if remove_word_size == 0:
        []
    else:
        for i in range(len(data)):
            if (len(letters[i][0:]) < remove_word_size+1 and len(letters[i][0:]) > remove_word_size-1):
                remove.append(data[i])
        return remove

def remove_list_ele(mas_list,remove_list):
    from collections import Counter
    a = mas_list
    b= remove_list
    c=list(Counter(a)-Counter(b))
    return c

def checker(output,data, prefix_level):
    data=sorted(data)
    if len(output) == len(data):
        flag = True
        print('Congrats! We identified all users using {} set of prefixes'.format(prefix_level))
    else:
        flag = False
        print('Find higher order features')
    return flag
#def check

# %%
#This functions builds the set of all first, second, third, nth order prefixes

def get_all_prefixes(data):
    #Initializing prefix extraction algorithm
    data = data
    remainder_data = data
    words = getwords(data)
    letters = getletters(words)
    sorted_words = sorted(data,key=len)
    max_prefix=sorted_words[-1]
    remove = []
    prefixes = []
    flag=False
    output = []
    
    #Collect 1st order prefixes
    if (len(max_prefix) > 0 and flag == False): 
        #Creates 0th char removal list
        #remove_0 = word_filter(data,letters,0)
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))

        remove=word_filter(remainder_data,letters,0)
        remainder_data = remove_list_ele(remainder_data,remove)
        #remainder_data = remove_list_ele(remainder_data,remove_0)
        words = getwords(remainder_data)
        letters = getletters(words)
        
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))

        for i in range(len(data)):
            prefixes.append(letters[i][0])
        print(len(remainder_data),len(data))
        print('Prefixes T1')
        print(prefixes)
        print('')
        print(remove)
        print('')
        #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
        
        print('OUTPUT1')
        print('')
        print(output)
        print('')
        print('DATABASE')
        print(sorted(database))
        print('')
        
        #Check if you got all the names using prefixes
        flag=checker(output,data,1)
        
    #Collect 2nd order prefixes
    if (len(max_prefix) > 1 and flag==False): 
        #Creates 1st char removal list
        #remove_1 = word_filter(data,letters,1)
        #remainder_data = remove_list_ele(remainder_data,remove_1)
        
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))
        
        remove= word_filter(remainder_data,letters,1)
        remainder_data = remove_list_ele(remainder_data,remove)
        words = getwords(remainder_data)
        letters = getletters(words)
        
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))

        for i in range(len(remainder_data)):
            prefixes.append(letters[i][0]+letters[i][1])  
            #prefixes.append(letters[i][0:1])  
        #prefixes = [y for x in prefixes for y in x]

        print('Prefixes T2')
        print(prefixes)

        #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
        
        print('OUTPUT2')
        print('')
        print(output)
        print('')
        print('DATABASE')
        print(sorted(data))
        print('')
        
        #Check if you got all the names using prefixes
        flag=checker(output,sorted(data),2)

    #Collect 3rd order prefixes
    if (len(max_prefix) > 2 and flag == False): 
        #Creates 2nd char removal list
        #remove_2 = word_filter(remainder_data,letters,2)
        #remainder_data = remove_list_ele(remainder_data,remove_2)
        
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))
        remove = word_filter(remainder_data,letters,2)
        remainder_data = remove_list_ele(remainder_data,remove)        
        words = getwords(remainder_data)
        letters = getletters(words)
        print(len(data),len(remainder_data),len(words),len(letters), len(prefixes))
        
        #add them in order; if not, you'll rearrange them
        for i in range(len(remainder_data)):
            prefixes.append(letters[i][0]+letters[i][1]+letters[i][2])  
        
        print('This is 2nd order removal')
        print(remove)
        
        #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
        
        print('OUTPUT3')
        print('')
        print(output)
        print('')
        print('DATABASE')
        print(sorted(data))
        
        #check if you got all the names
        flag=checker(output,data,3)

    #Collect 4th order prefixes
    if (len(max_prefix) > 3 and flag == False): 
        #Creates 3rd char removal list
        #remove_3 = word_filter(remainder_data,letters,3)
        #remainder_data = remove_list_ele(remainder_data,remove_3)
        #words = getwords(remainder_data)
        #letters = getletters(words)
        
        remove = word_filter(remainder_data,letters,3)
        remainder_data = remove_list_ele(remainder_data,remove)        
        words = getwords(remainder_data)
        letters = getletters(words)
        
        for i in range(len(remainder_data)):
            prefixes.append(letters[i][0]+letters[i][1]+letters[i][2]+letters[i][3]) 
        
        #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
        
        print('OUTPUT4')
        print('')
        print(output)
        print('')
        print('DATABASE')        
        print(sorted(data))
       
        #check if you got all the names        
        flag=checker(output,data,4)

    #5th order prefix
    if (len(max_prefix) > 4 and flag == False): 
        #Creates 5th char removal list
        remove_4 = word_filter(remainder_data,letters,4)
        remainder_data = remove_list_ele(remainder_data,remove_4)
        words = getwords(remainder_data)
        letters = getletters(words)
        
        for i in range(len(remainder_data)):
            prefixes.append(letters[i][0]+letters[i][1]+letters[i][2]+letters[i][3]+letters[i][4]) 
        
        #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
        
        print('OUTPUT5')
        print('')
        print(output)
        print('')
        print('DATABASE')        
        print(sorted(data))
        
        #check if you got all the names        
        flag=checker(output,data,5)

    #6th order prefix
    if (len(max_prefix) > 5 and flag == False): 
        #Creates 6th char removal list
        remove_5 = word_filter(remainder_data,letters,5)
        remainder_data = remove_list_ele(remainder_data,remove_5)
        words = getwords(remainder_data)
        letters = getletters(words)
        
        for i in range(len(remainder_data)):
            prefixes.append(letters[i][0]+letters[i][1]+letters[i][2]+letters[i][3]+letters[i][4]+letters[i][5]) 
        
         #TO DO: REBUILD DATASET
        for i in range(len(prefixes)):
            output=sorted(list(set(output+query(prefixes[i]))))
         
        print('OUTPUT6')
        print('')
        print(output)
        print('')
        print('DATABASE')        
        print(sorted(data))
        
        #check if you got all the names        
        flag=checker(output,data,6)
        print(remove_list_ele(data,output))
        
    return prefixes

prefixes=get_all_prefixes(database)
prefixes
# Out:
# 1064 1064 1064 1064 0
# 1064 1064 1064 1064 0
# 1064 1064
# Prefixes T1
# ['k', 's', 't', 'm', 'd', 'g', 'x', 'l', 'q', 'c', 't', 'm', 'j', 'g', 'z', 'x', 'z', 'g', 't', 'm', 'q', 's', 'x', 'f', 'k', 'j', 't', 'd', 's', 'r', 'f', 'j', 'h', 'f', 't', 'k', 'v', 'x', 'h', 'l', 'b', 'm', 'j', 'm', 'g', 'l', 'q', 'b', 'w', 'l', 'n', 'q', 'k', 'v', 'v', 'c', 'r', 'g', 's', 'k', 'p', 'h', 'k', 't', 'n', 'r', 'v', 'w', 'm', 'g', 'c', 'g', 'g', 'q', 'l', 'q', 's', 'g', 'y', 'x', 'f', 'g', 'l', 'j', 'q', 'n', 'x', 'j', 'j', 'n', 'j', 'z', 'r', 'm', 'm', 'j', 't', 'w', 's', 'l', 'g', 'z', 'v', 'n', 'k', 's', 'y',
jaz', 'je', 'jecu', 'jefe', 'jeh', 'jeja', 'jeji', 'jel', 'jela', 'jem', 'jemi', 'jero', 'jes', 'jey', 'jeza', 'ji', 'jibo', 'jil', 'jisi', 'jiti', 'jiv', 'jiwa', 'jiy', 'jo', 'jof', 'joji', 'jolu', 'jom', 'jopi', 'jor', 'joru', 'joxi', 'jozu', 'ju', 'jud', 'jupo', 'juq', 'jur', 'juta', 'juti', 'juv', 'juyu', 'k', 'ka', 'kabi', 'kagi', 'kam', 'kan', 'kas', 'kav', 'ke', 'keci', 'ked', 'kego', 'kel', 'kewi', 'kexa', 'ki', 'kic', 'kice', 'kid', 'kiha', 'kija', 'kije', 'kimu', 'kiq', 'kito', 'kix', 'ko', 'kob', 'koh', 'koho', 'koja', 'koji', 'koko', 'kom', 'kop', 'kose', 'koyo', 'koyu', 'ku', 'kuba', 'kug', 'kuji', 'kula', 'kun', 'kup', 'kut', 'kuxe', 'kuy', 'l', 'la', 'lab', 'ladu', 'lam', 'lav', 'le', 'lehi', 'lej', 'leku', 'lele', 'lena', 'lep', 'les', 'lesu', 'let', 'lev', 'lex', 'lexe', 'lexu', 'lez', 'lezo', 'li', 'lif', 'lifo', 'lila', 'lip', 'lir', 'lo', 'lob', 'loco', 'log', 'lom', 'lone', 'loq', 'lov', 'love', 'lowu', 'loy', 'lu', 'lub', 'luf', 'luge', 'luki', 'lun', 'lunu', 'luso', 'luv', 'luwi', 'luxe', 'luyu', 'm', 'ma', 'mabe', 'macu', 'mafu', 'mat', 'mav', 'mavu', 'maw', 'me', 'meco', 'megi', 'meha', 'mete', 'mi', 'mibe', 'mic', 'midi', 'mife', 'migi', 'mih', 'miq', 'miso', 'mo', 'mob', 'mok', 'mom', 'mon', 'moq', 'mos', 'mosa', 'moso', 'moy', 'mu', 'mubi', 'muda', 'mug', 'muji', 'muk', 'muki', 'mul', 'mum', 'munu', 'mupu', 'muq', 'mura', 'muro', 'muv', 'muva', 'muyu', 'n', 'na', 'nab', 'nag', 'nala', 'name', 'naq', 'naqo', 'nar', 'nav', 'nayu', 'naz', 'nazi', 'ne', 'nek', 'nemo', 'nepi', 'nev', 'ni', 'nici', 'nifu', 'nij', 'niq', 'nita', 'nito', 'niv', 'niy', 'niz', 'nofo', 'nole', 'nona', 'not', 'now', 'nox', 'noye', 'nu', 'nub', 'nuj', 'nuji', 'nuk', 'nup', 'nupa', 'nuqu', 'nuru', 'nuw', 'nuxu', 'p', 'pa', 'pab', 'pahe', 'paj', 'paqi', 'paw', 'pax', 'pay', 'pe', 'pega', 'pegi', 'peh', 'pep', 'peqe', 'peto', 'pex', 'pe ...
# Congrats! We identified all users using 3 set of prefixes
# ['k',
#  's',
#  't',
#  'm',
#  'd',
#  'g',
#  'x',
#  'l',
#  'q',
#  'c',
#  't',
#  'm',
#  'j',
#  'g',
#  'z',
#  'x',
#  'z',
#  'g',
#  't',
#  'm',
#  'q',
#  's',
#  'x',
#  'f',
#  'k',
#  'j',
#  't',
#  'd',
#  's',
#  'r',
#  'f',
#  'j',
#  'h',
#  'f',
#  't',
#  'k',
#  'v',
#  'x',
#  'h',
#  'l',
#  'b',
#  'm',
#  'j',
#  'm',
#  'g',
#  'l',
#  'q',
#  'b',
#  'w',
#  'l',
#  'n',
#  'q',
#  'k',
#  'v',
#  'v',
#  'c',
#  'r',
#  'g',
#  's',
#  'k',
#  'p',
#  'h',
#  'k',
#  't',
#  'n',
#  'r',
#  'v',
#  'w',
#  'm',
#  'g',
#  'c',
#  'g',
#  'g',
#  'q',
#  'l',
#  'q',
#  's',
#  'g',
#  'y',
#  'x',
#  'f',
#  'g',
#  'l',
#  'j',
#  'q',
#  'n',
#  'x',
#  'j',
#  'j',
#  'n',
#  'j',
#  'z',
#  'r',
#  'm',
#  'm',
#  'j',
#  't',
#  'w',
#  's',
#  'l',
#  'g',
#  'z',
#  'v',
#  'n',
#  'k',
#  's',
#  'y',
#  'r',
#  'j',
#  'w',
#  'r',
#  'y',
#  'c',
#  'f',
#  'g',
#  'j',
#  'w',
#  's',
#  'w',
#  'z',
#  'm',
#  'j',
#  'm',
#  'm',
#  'q',
#  'r',
#  'p',
#  'g',
#  'b',
#  's',
#  'q',
#  't',
#  'q',
#  's',
#  'n',
#  'n',
#  'd',
#  'b',
#  'k',
#  'g',
#  'q',
#  'g',
#  'p',
#  'k',
#  'm',
#  'p',
#  'v',
#  'h',
#  'h',
#  'm',
#  'r',
#  'b',
#  'z',
#  'q',
#  'r',
#  'm',
#  'w',
#  'm',
#  't',
#  'd',
#  'm',
#  'q',
#  'c',
#  'g',
#  'c',
#  'y',
#  'c',
#  'p',
#  'v',
#  'q',
#  'q',
#  'd',
#  'n',
#  'r',
#  's',
#  'z',
#  'j',
#  'c',
#  'm',
#  'd',
#  'k',
#  'y',
#  'm',
#  'x',
#  'z',
#  'p',
#  'x',
#  'f',
#  'v',
#  'j',
#  'y',
#  'p',
#  'h',
#  'q',
#  'r',
#  'p',
#  'm',
#  'c',
#  'y',
#  'x',
#  'n',
#  'r',
#  'c',
#  'n',
#  'z',
#  'g',
#  'n',
#  'b',
#  'k',
#  'r',
#  'v',
#  'x',
#  'q',
#  'c',
#  'p',
#  'm',
#  'v',
#  's',
#  'f',
#  's',
#  'p',
#  'p',
#  'j',
#  'n',
#  't',
#  'l',
#  'b',
#  'j',
#  'n',
#  'b',
#  't',
#  'v',
#  'l',
#  'c',
#  'p',
#  'j',
#  'r',
#  'm',
#  'j',
#  'm',
#  't',
#  'd',
#  'l',
#  't',
#  'r',
#  'g',
#  'k',
#  'z',
#  'j',
#  'q',
#  'b',
#  'p',
#  'f',
#  'r',
#  't',
#  'b',
#  'm',
#  'x',
#  'w',
#  'z',
#  'k',
#  'k',
#  'y',
#  'x',
#  'g',
#  'f',
#  'q',
#  'j',
#  'v',
#  'k',
#  'j',
#  'y',
#  's',
#  'm',
#  'c',
#  'c',
#  's',
#  'd',
#  'h',
#  't',
#  'j',
#  's',
#  'n',
#  'w',
#  'b',
#  's',
#  'g',
#  'h',
#  'c',
#  'f',
#  'b',
#  'g',
#  'h',
#  'n',
#  'l',
#  'j',
#  'w',
#  't',
#  'b',
#  'l',
#  's',
#  'm',
#  'q',
#  'd',
#  'd',
#  'b',
#  'j',
#  'v',
#  'k',
#  'c',
#  'k',
#  'r',
#  'n',
#  'q',
#  'd',
#  'x',
#  'd',
#  'w',
#  'w',
#  'v',
#  'g',
#  'b',
#  'q',
#  'r',
#  'w',
#  'm',
#  's',
#  'p',
#  'b',
#  'd',
#  'g',
#  'q',
#  'm',
#  's',
#  'z',
#  'b',
#  'l',
#  'k',
#  'n',
#  'p',
#  'p',
#  'x',
#  'q',
#  't',
#  'j',
#  'b',
#  'w',
#  'b',
#  'r',
#  't',
#  'p',
#  'c',
#  'f',
#  'l',
#  'h',
#  'l',
#  'h',
#  'm',
#  'y',
#  'l',
#  'j',
#  'b',
#  'j',
#  'x',
#  'g',
#  't',
#  'g',
#  't',
#  'y',
#  's',
#  'v',
#  'f',
#  'f',
#  'x',
#  'g',
#  's',
#  'k',
#  'x',
#  'p',
#  'r',
#  'y',
#  'm',
#  't',
#  'j',
#  'z',
#  'q',
#  'z',
#  'h',
#  'z',
#  'h',
#  'd',
#  'l',
#  's',
#  'h',
#  'b',
#  'z',
#  'g',
#  'x',
#  'y',
#  'k',
#  'f',
#  'f',
#  'r',
#  's',
#  'p',
#  'p',
#  'x',
#  'l',
#  'p',
#  'r',
#  'l',
#  'r',
#  'd',
#  'l',
#  'z',
#  'h',
#  'n',
#  'm',
#  'v',
#  'r',
#  'l',
#  'r',
#  'g',
#  'b',
#  'm',
#  'y',
#  'z',
#  'b',
#  't',
#  'r',
#  'g',
#  'h',
#  'w',
#  'j',
#  'j',
#  's',
#  's',
#  'w',
#  'b',
#  'l',
#  'h',
#  'q',
#  'g',
#  'b',
#  'm',
#  'p',
#  'c',
#  'r',
#  'x',
#  'x',
#  'j',
#  'p',
#  'p',
#  'p',
#  'c',
#  'v',
#  'x',
#  'l',
#  'n',
#  'p',
#  'k',
#  'n',
#  's',
#  'k',
#  'c',
#  'r',
#  'j',
#  'x',
#  'l',
#  'b',
#  'l',
#  's',
#  'y',
#  'w',
#  'l',
#  'x',
#  'q',
#  'p',
#  'z',
#  'c',
#  'f',
#  's',
#  'x',
#  'y',
#  'j',
#  'y',
#  'l',
#  'h',
#  'r',
#  'w',
#  'm',
#  'm',
#  'q',
#  'x',
#  'p',
#  'h',
#  'p',
#  'v',
#  'j',
#  'v',
#  'n',
#  'k',
#  'w',
#  'w',
#  'c',
#  'l',
#  'z',
#  'm',
#  'm',
#  'y',
#  'k',
#  'n',
#  'v',
#  'b',
#  'b',
#  'y',
#  'p',
#  'd',
#  's',
#  'd',
#  'n',
#  'f',
#  'd',
#  'w',
#  'n',
#  'r',
#  'w',
#  'j',
#  'r',
#  'f',
#  'f',
#  'p',
#  'd',
#  'v',
#  'z',
#  'c',
#  's',
#  'f',
#  'l',
#  'z',
#  'h',
#  'z',
#  'b',
#  'f',
#  'm',
#  'g',
#  'l',
#  'c',
#  'v',
#  'n',
#  'y',
#  'l',
#  'c',
#  'v',
#  'f',
#  'p',
#  'w',
#  's',
#  'k',
#  'd',
#  'b',
#  'q',
#  'p',
#  'f',
#  'c',
#  'g',
#  'k',
#  't',
#  'h',
#  'm',
#  'v',
#  'y',
#  'r',
#  'c',
#  'g',
#  'f',
#  'y',
#  'h',
#  'r',
#  'l',
#  'c',
#  'm',
#  'v',
#  'f',
#  'n',
#  'd',
#  'r',
#  'v',
#  'k',
#  'w',
#  'g',
#  't',
#  'd',
#  'g',
#  'w',
#  'h',
#  'p',
#  'q',
#  'n',
#  'h',
#  'y',
#  's',
#  'j',
#  'p',
#  'd',
#  'f',
#  'b',
#  'j',
#  'p',
#  'z',
#  'n',
#  'p',
#  'n',
#  'm',
#  'f',
#  'w',
#  'k',
#  't',
#  'p',
#  'b',
#  'x',
#  'q',
#  'k',
#  'x',
#  'j',
#  's',
#  'v',
#  'd',
#  'x',
#  'h',
#  'h',
#  'r',
#  'x',
#  'm',
#  'd',
#  'q',
#  't',
#  'g',
#  'h',
#  'w',
#  'g',
#  'k',
#  's',
#  'w',
#  'y',
#  'n',
#  'z',
#  'd',
#  'r',
#  'q',
#  'l',
#  'g',
#  'q',
#  'h',
#  'w',
#  'q',
#  'v',
#  't',
#  'w',
#  'n',
#  'd',
#  't',
#  'y',
#  'r',
#  's',
#  's',
#  'b',
#  'z',
#  'f',
#  'k',
#  'n',
#  'q',
#  'b',
#  'j',
#  's',
#  'q',
#  'w',
#  'g',
#  'd',
#  'x',
#  'v',
#  'b',
#  'b',
#  'y',
#  'v',
#  'g',
#  'k',
#  'y',
#  'f',
#  'w',
#  'w',
#  'y',
#  'v',
#  'j',
#  'y',
#  't',
#  'z',
#  'k',
#  'n',
#  'd',
#  'r',
#  'd',
#  'h',
#  'v',
#  's',
#  'j',
#  'l',
#  'b',
#  'p',
#  'n',
#  't',
#  'g',
#  'f',
#  'f',
#  'p',
#  'q',
#  'j',
#  's',
#  's',
#  'q',
#  'c',
#  'w',
#  'c',
#  'r',
#  'd',
#  'v',
#  'm',
#  'n',
#  'v',
#  'v',
#  'l',
#  'g',
#  'l',
#  'y',
#  'x',
#  'w',
#  'z',
#  'c',
#  'y',
#  'c',
#  'p',
#  'g',
#  'c',
#  'l',
#  't',
#  'q',
#  'p',
#  'x',
#  'x',
#  'x',
#  'l',
#  'v',
#  't',
#  'q',
#  'h',
#  'b',
#  'v',
#  'k',
#  'z',
#  'l',
#  'l',
#  'q',
#  'l',
#  'x',
#  'b',
#  'z',
#  'n',
#  'v',
#  'z',
#  'x',
#  'j',
#  'c',
#  'm',
#  'y',
#  'v',
#  't',
#  'd',
#  'w',
#  'r',
#  'v',
#  'z',
#  'y',
#  'r',
#  'w',
#  's',
#  'm',
#  'w',
#  'c',
#  'z',
#  'c',
#  'h',
#  'k',
#  's',
#  'h',
#  's',
#  'x',
#  'd',
#  'v',
#  'l',
#  'v',
#  'k',
#  's',
#  'x',
#  's',
#  'v',
#  'm',
#  'h',
#  'z',
#  't',
#  'q',
#  'r',
#  'f',
#  's',
#  'd',
#  'b',
#  'r',
#  'w',
#  'q',
#  'd',
#  'l',
#  'p',
#  'b',
#  'k',
#  'c',
#  'v',
#  'h',
#  'q',
#  'z',
#  'k',
#  's',
#  's',
#  'g',
#  'f',
#  'y',
#  'x',
#  'w',
#  'l',
#  'm',
#  'z',
#  'd',
#  'd',
#  't',
#  'x',
#  's',
#  'd',
#  'v',
#  'j',
#  'w',
#  'j',
#  'c',
#  'q',
#  'r',
#  'w',
#  't',
#  't',
#  'd',
#  'z',
#  'w',
#  'l',
#  'c',
#  'c',
#  'p',
#  'g',
#  'b',
#  'z',
#  's',
#  't',
#  'y',
#  'r',
#  'g',
#  'k',
#  'p',
#  'f',
#  'm',
#  'n',
#  'c',
#  'k',
#  'c',
#  'k',
#  't',
#  'q',
#  'z',
#  'n',
#  'z',
#  'z',
#  'f',
#  'r',
#  'v',
#  'j',
#  'n',
#  'l',
#  'h',
#  'h',
#  't',
#  'v',
#  't',
#  'x',
#  'r',
#  'y',
#  'k',
#  'z',
#  'y',
#  'm',
#  'g',
#  't',
#  'd',
#  's',
#  'z',
#  'c',
#  'p',
#  'd',
#  'g',
#  'j',
#  'l',
#  'h',
#  'g',
#  'n',
#  'w',
#  'q',
#  'g',
#  'r',
#  'w',
#  'p',
#  'p',
#  'n',
#  't',
#  'p',
#  'f',
#  'r',
#  'y',
#  'd',
#  'z',
#  'q',
#  'w',
#  'x',
#  'h',
#  'j',
#  's',
#  'd',
#  'x',
#  'j',
#  't',
#  'y',
#  'h',
#  'd',
#  'r',
#  'x',
#  'k',
#  'x',
#  's',
#  'z',
#  'z',
#  'w',
#  'w',
#  'k',
#  'z',
#  'b',
#  'z',
#  'h',
#  'p',
#  'p',
#  'c',
#  'k',
#  'k',
#  's',
#  'm',
#  'y',
#  'v',
#  'x',
#  'g',
#  'v',
#  'q',
#  'q',
#  'n',
#  'q',
#  'b',
#  'm',
#  'w',
#  'z',
#  'x',
#  'g',
#  'x',
#  'y',
#  'k',
#  'v',
#  'd',
#  's',
#  'f',
#  'w',
#  'h',
#  'g',
#  'x',
#  'h',
#  'v',
#  'x',
#  'n',
#  'd',
#  'r',
#  'd',
#  'j',
#  ...]

# %%
#This is incomplete


def build_data(i_prefixes, data):
    data_f = []
    count = 0
    for i in range(len(data)):
        data_f.append(query(i_prefixes[i]))
        count+=1
    data_f = [item for sublist in data_f for item in sublist]
    
    if data_f != data:
        data_r = sorted(remove_list_ele(data, data_f))
        #sorted(list(set(data)-set(data_f_t)))
        print((data_r))
    else:
        data_r=[]
    
    return data_f, data_r, count

# %%
prefixes = get_all_prefixes(database)
data_f, data_r, count = build_data(prefixes,database)

print('')
print(sorted(data_f))
print('')
print(data_r)
print('')
print(prefixes)
print('')
print(database)
print('')
print(len(prefixes))
print('')
print(len(database))

if data_f == database:
    print('we did it boi with {} querys'.format(count))
else:
    print('')
    print('aw')
    print('Here is what we missed')
    print(sorted(remove_list_ele(database,data_f)))
# Out:
# Prefixes T1
# ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'g', 'g', 'g', 'g', 'g', 'g', 'h', 'h', 'h', 'h', 'h', 'h', 'h', 'j', 'j', 'j', 'j', 'j', 'j', 'j', 'k', 'k', 'k', 'k', 'k', 'k', 'k', 'k', 'k', 'k', 'k', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'p', 'p', 'p', 'p', 'p', 'p', 'p', 'q', 'q', 'q', 'q', 'q', 'q', 'q', 'q', 'q', 'q', 'q', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 's', 's', 's', 's', 's', 't', 't', 't', 't', 't', 't', 't', 't', 't', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'v', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'x', 'x', 'x', 'x', 'x', 'x', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'y', 'z', 'z', 'z', 'z']
#
# OUTPUT1
#
# ['b', 'ba', 'be', 'ben', 'bom', 'c', 'ca', 'ceh', 'cer', 'ci', 'd', 'da', 'deq', 'di', 'dit', 'f', 'fa', 'fah', 'feg', 'fi', 'g', 'ga', 'gav', 'gaw', 'ge', 'h', 'ha', 'hec', 'hey', 'hiq', 'j', 'jaf', 'je', 'jes', 'jix', 'k', 'kaj', 'ke', 'kep', 'kib', 'l', 'la', 'leh', 'lih', 'lil', 'm', 'ma', 'me', 'mip', 'mo', 'n', 'na', 'naw', 'nex', 'ni', 'p', 'pe', 'pi', 'po', 'poz', 'q', 'qa', 'qav', 'qe', 'qex', 'r', 'rat', 're', 'rev', 'rip', 's', 'sa', 'sal', 'se', 'so', 't', 'ta', 'taq', 'te', 'tek', 'v', 've', 'vel', 'ver', 'vet', 'w', 'we', 'weh', 'wej', 'wek', 'x', 'xa', 'xad', 'xe', 'xih', 'y', 'ya', 'ye', 'yeb', 'yer', 'z', 'zi', 'zo', 'zu']
#
# DATABASE
# ['b', 'ba', 'be', 'ben', 'bom', 'bu', 'buk', 'bul', 'c', 'ca', 'ceh', 'cer', 'ci', 'cin', 'co', 'cu', 'd', 'da', 'deq', 'di', 'dit', 'do', 'duf', 'dul', 'f', 'fa', 'fah', 'feg', 'fi', 'fib', 'fiw', 'fix', 'fo', 'fos', 'fu', 'fub', 'fuk', 'g', 'ga', 'gav', 'gaw', 'ge', 'gu', 'h', 'ha', 'hec', 'hey', 'hiq', 'ho', 'hu', 'j', 'jaf', 'je', 'jes', 'jix', 'jo', 'job', 'k', 'kaj', 'ke', 'kep', 'kib', 'kiy', 'ko', 'kof', 'kog', 'ku', 'kuz', 'l', 'la', 'leh', 'lih', 'lil', 'lo', 'lof', 'lov', 'low', 'luq', 'lus', 'm', 'ma', 'me', 'mip', 'mo', 'mod', 'mol', 'mu', 'n', 'na', 'naw', 'nex', 'ni', 'nit', 'no', 'nok', 'nom', 'not', 'nu', 'nuq', 'nur', 'p', 'pe', 'pi', 'po', 'poz', 'pu', 'put', 'q', 'qa', 'qav', 'qe', 'qex', 'qi', 'qir', 'qo', 'qom', 'qu', 'quq', 'r', 'rat', 're', 'rev', 'rip', 'ru', 'ruh', 'ruv', 's', 'sa', 'sal', 'se', 'so', 't', 'ta', 'taq', 'te', 'tek', 'tex', 'tov', 'tu', 'tum', 'v', 've', 'vel', 'ver', 'vet', 'vi', 'vih', 'vod', 'vog', 'vos', 'voy', 'vug', 'w', 'we', 'weh', 'wej', 'wek', 'wew', 'wip', 'wu', 'x', 'xa', 'xad', 'xe', 'xih', 'xog', 'y', 'ya', 'ye', 'yeb', 'yer', 'yes', 'yi', 'yib', 'yim', 'yin', 'yo', 'yon', 'yu', 'yuk', 'z', 'zi', 'zo', 'zu']
#
# Find higher order features
# Prefixes T2
# ['b', 'b', 'b', 'b', 'b', 'b', 'b', 'b', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'c', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'd', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 'f', 
 'qom', 'qu', 'quq', 'r', 'rat', 're', 'rev', 'rip', 'ru', 'ruh', 'ruv', 's', 'sa', 'sal', 'se', 'so', 't', 'ta', 'taq', 'te', 'tek', 'tex', 'tov', 'tu', 'tum', 'v', 've', 'vel', 'ver', 'vet', 'vi', 'vih', 'vod', 'vog', 'vos', 'voy', 'vug', 'w', 'we', 'weh', 'wej', 'wek', 'wew', 'wip', 'wu', 'x', 'xa', 'xad', 'xe', 'xih', 'xog', 'y', 'ya', 'ye', 'yeb', 'yer', 'yes', 'yi', 'yib', 'yim', 'yin', 'yo', 'yon', 'yu', 'yuk', 'z', 'zi', 'zo', 'zu']
#
# 347
#
# 184
#
# aw
# Here is what we missed
# ['bu', 'buk', 'bul', 'cin', 'co', 'cu', 'do', 'duf', 'dul', 'fib', 'fiw', 'fix', 'fo', 'fos', 'fu', 'fub', 'fuk', 'gu', 'ho', 'hu', 'jo', 'job', 'kiy', 'ko', 'kof', 'kog', 'ku', 'kuz', 'lo', 'lof', 'lov', 'low', 'luq', 'lus', 'mod', 'mol', 'mu', 'nit', 'no', 'nok', 'nom', 'not', 'nu', 'nuq', 'nur', 'pu', 'put', 'qi', 'qir', 'qo', 'qom', 'qu', 'quq', 'ru', 'ruh', 'ruv', 'tex', 'tov', 'tu', 'tum', 'vi', 'vih', 'vod', 'vog', 'vos', 'voy', 'vug', 'wew', 'wip', 'wu', 'xog', 'yes', 'yi', 'yib', 'yim', 'yin', 'yo', 'yon', 'yu', 'yuk']

# %%
def get_remainder_prefixes(data_left):
    prefix_cont=get_all_prefixes(data_left,2)
    data_cont, data_r_cont, count = build_data_f_t(prefixes_cont, data_left)

# %%
while (data_r != []):
    prefixes = get_all_prefixes(database,2)
    data_f_t, data_r_t, count = build_data_f_t(prefixes,database)
    print(data_r_t)

    if data_f_t == database:
        print('we did it boi with {} querys'.format(count))
    else:
        print('aw')

# %%
query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]

# %% [markdown]
# data_r = []
# while (data_f_t != database):
#     #prefixes = get_all_prefixes(data_r,1)
#     #data_f_t = build_data_f_t(prefixes, data_r)
#     #data_r = sorted(list(set(database)-set(data_f_t)))
#
#     if (data_f_t == database):
#         print('sucess')
#     elif (data_r == database):
#         print('flag')
#         break
#
# data_r
# query = lambda prefix: [d for d in database if d.startswith(prefix)][:5]

# %% [markdown]
# def test(data, num_prefixes):
#
#     sorted_words = sorted(data,key=len)
#     max_prefix=sorted_words[-1]
#
#     chars = []
#     for x in range(len(data)):
#         listChar=list(data[x])
#         chars.append(listChar)
#     #return chars
#
#     for i in range(len(data)):
#         letter=chars[i][0:]
#         letters.append(letter)
#     #return letters
#
#     prefixes=[]
#
#     for j in range(len(max_prefix)-1):
#         for i in range(len(data)):
#             prefixes.append((letters[i][j]))
#
#     return prefixes

# %%
a = ['adr','asd','ds','asd']
sorted_words = sorted(a,key=len)
max_prefix=sorted_words[-1]
len(max_prefix)

b = []
for j in range(len(max_prefix)):
    for i in range(len(a)):
        b[j] += a[i]
